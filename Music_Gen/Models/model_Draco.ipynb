# %% [markdown]
# # Model Draco

# %% [markdown]
# * Adjust the weight of the loss function MSE and similarity
# * The way convolutions are referenced in decoder

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import librosa
from note_seq.protobuf import music_pb2
from note_seq.midi_synth import fluidsynth
from note_seq import sequences_lib
from note_seq import audio_io
from note_seq import midi_io
from pydub import AudioSegment
import tensorflow as tf
from note_seq import note_sequence_to_midi_file, NoteSequence, midi_to_note_sequence
from magenta.models.music_vae import TrainedModel, configs

import pandas as pd
import torch
import clip
from PIL import Image
import os
from sklearn.metrics.pairwise import cosine_similarity

import torch
import torch.nn as nn
import note_seq

from tensorflow.keras.layers import Input, Dense, Lambda, LSTM, RNN, LSTMCell, RepeatVector, TimeDistributed, Layer, Dropout, BatchNormalization, LeakyReLU, MultiHeadAttention, LayerNormalization, Reshape, Conv1DTranspose, Activation, Cropping1D, ReLU, Conv1D
from tensorflow.keras import Model
from tensorflow.keras import backend as K

from sklearn.model_selection import train_test_split

from tensorflow.keras.optimizers import Adam, SGD
from tqdm import tqdm

import h5py
import json

from tensorflow.keras.models import load_model
from scipy.io.wavfile import write
import fluidsynth

from nltk.corpus import opinion_lexicon
from nltk.tokenize import word_tokenize
import random

# %% [markdown]
# ## Load Dataset

# %%
# Load processed matched musical data, which has deleted the no-sound audio row of data
base_data = pd.read_csv("processed_music_matched_data.csv")
base_data
# Out:
#                                                   Artwork  \
# 0       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 1       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 2       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 3       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 4       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# ...                                                   ...
# 422756                          david-burliuk_landscape-1
# 422757                           gino-severini_a-dancer-1
# 422758                  ivan-aivazovsky_sea-at-night-1861
# 422759                  ivan-aivazovsky_sea-at-night-1861
# 422760                  ivan-aivazovsky_sea-at-night-1861
#
#                                             Art_Utterance  \
# 0       She seems very happy in the picture, and you w...
# 1       This woman has really knotty hands which makes...
# 2       When looking at this woman, I am filled with c...
# 3       A woman looking at ease, peaceful, and satisfi...
# 4       She looks like a lady from that past that migh...
# ...                                                   ...
# 422756  The greenery landscape and flowery background ...
# 422757  the collection and collage of different colors...
# 422758  The peaceful reflections of the moonlight on t...
# 422759  I can imagine the sailors resting this peacefu...
# 422760  The steep mountains and the moonlight provide ...
#
#                  Music_Name  \
# 0         ABVYSaLu_VM_10-20
# 1       vnwKpQeza3A_320-330
# 2         0VwX92X3iPc_30-40
# 3       kh6rmFg3U4k_480-490
# 4       -VI2IRq17rs_360-370
# ...                     ...
# 422756     M0ygCD6WyXw_0-10
# 422757     oMZcsGUi8ZE_0-10
# 422758    s1QeDT7jqHQ_30-40
# 422759    ABVYSaLu_VM_10-20
# 422760    8q0An6WY7_c_10-20
#
#                                             Music_Comment  Similarity_Score
# 0       Here we have a slow piano piece played in a ma...          0.791458
# 1       This is a recording of two didgeridoos. They a...          0.772168
# 2       This audio contains a female voice speaking in...          0.798202
# 3       The low quality recording features a resonatin...          0.792188
# 4       In this clip, a large bell is rung and left to...          0.740201
# ...                                                   ...               ...
# 422756  This clip consists of a blowing horn being pla...          0.758374
# 422757  This clip features a synchronised playing of s...          0.799300
# 422758  The low quality recording features multiple la...          0.781008
# 422759  Here we have a slow piano piece played in a ma...          0.733153
# 422760  The low quality recording features a theremin ...          0.761976
#
# [422761 rows x 5 columns]

# %% [markdown]
# ### Load Dataset with Extracted Features

# %%
# load HDF5 file
with h5py.File('processed_data_with_melody2.h5', 'r') as hf:
    melody_data = hf['melody'][:]
    # Deserialize the JSON string to the Melody object
    melodies = [note_seq.Melody(json.loads(m.decode())) for m in melody_data]

    image_features = hf['image_features'][:]
    text_features = hf['text_features'][:]
    features_mean = hf['features_mean'][:]
    features_weighted = hf['features_weighted'][:]
    combined_features = hf['combined_features'][:]

# Convert the array to a list and add it to other_data DataFrame
base_data['image_features'] = list(image_features)
base_data['text_features'] = list(text_features)
base_data['features_mean'] = list(features_mean)
base_data['features_weighted'] = list(features_weighted)
base_data['melody'] = list(melodies)
base_data['combined_features'] = list(combined_features)

# %%
base_data
# Out:
#                                                   Artwork  \
# 0       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 1       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 2       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 3       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 4       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# ...                                                   ...
# 422756                          david-burliuk_landscape-1
# 422757                           gino-severini_a-dancer-1
# 422758                  ivan-aivazovsky_sea-at-night-1861
# 422759                  ivan-aivazovsky_sea-at-night-1861
# 422760                  ivan-aivazovsky_sea-at-night-1861
#
#                                             Art_Utterance  \
# 0       She seems very happy in the picture, and you w...
# 1       This woman has really knotty hands which makes...
# 2       When looking at this woman, I am filled with c...
# 3       A woman looking at ease, peaceful, and satisfi...
# 4       She looks like a lady from that past that migh...
# ...                                                   ...
# 422756  The greenery landscape and flowery background ...
# 422757  the collection and collage of different colors...
# 422758  The peaceful reflections of the moonlight on t...
# 422759  I can imagine the sailors resting this peacefu...
# 422760  The steep mountains and the moonlight provide ...
#
#                  Music_Name  \
# 0         ABVYSaLu_VM_10-20
# 1       vnwKpQeza3A_320-330
# 2         0VwX92X3iPc_30-40
# 3       kh6rmFg3U4k_480-490
# 4       -VI2IRq17rs_360-370
# ...                     ...
# 422756     M0ygCD6WyXw_0-10
# 422757     oMZcsGUi8ZE_0-10
# 422758    s1QeDT7jqHQ_30-40
# 422759    ABVYSaLu_VM_10-20
# 422760    8q0An6WY7_c_10-20
#
#                                             Music_Comment  Similarity_Score  \
# 0       Here we have a slow piano piece played in a ma...          0.791458
# 1       This is a recording of two didgeridoos. They a...          0.772168
# 2       This audio contains a female voice speaking in...          0.798202
# 3       The low quality recording features a resonatin...          0.792188
# 4       In this clip, a large bell is rung and left to...          0.740201
# ...                                                   ...               ...
# 422756  This clip consists of a blowing horn being pla...          0.758374
# 422757  This clip features a synchronised playing of s...          0.799300
# 422758  The low quality recording features multiple la...          0.781008
# 422759  Here we have a slow piano piece played in a ma...          0.733153
# 422760  The low quality recording features a theremin ...          0.761976
#
#                                            image_features  \
# 0       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 1       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 2       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 3       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 4       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# ...                                                   ...
# 422756  [0.2013, -0.2996, 0.1554, -0.04733, 0.1796, -0...
# 422757  [0.282, 0.1711, 0.1952, -0.1887, 0.417, 0.0896...
# 422758  [0.1924, -0.2947, 0.07135, 0.392, 0.2793, -0.0...
# 422759  [0.1924, -0.2947, 0.07135, 0.392, 0.2793, -0.0...
# 422760  [0.1924, -0.2947, 0.07135, 0.392, 0.2793, -0.0...
#
#                                             text_features  \
# 0       [-0.0315, 0.1757, -0.1968, 0.0465, -0.04526, -...
# 1       [-0.0724, 0.3037, -0.4678, -0.1588, 0.1721, 0....
# 2       [0.05783, -0.0409, -0.4458, -0.0473, -0.08594,...
# 3       [0.1517, -0.2998, 0.1375, 0.3303, 0.3237, -0.5...
# 4       [-0.1611, -0.002035, -0.2603, 0.1305, 0.1753, ...
# ...                                                   ...
# 422756  [0.06445, 0.1355, 0.3389, -0.1179, -0.04034, 0...
# 422757  [-0.05054, 0.3774, 0.2979, -0.06555, -0.04782,...
# 422758  [0.0625, -0.1382, 0.1168, 0.2683, 0.3545, -0.1...
# 422759  [-0.01753, -0.018, 0.11707, -0.0385, 0.2886, 0...
# 422760  [-0.2, -0.1665, 0.2362, 0.0648, 0.2886, 0.0142...
#
#                                             features_mean  \
# 0       [0.1167, 0.002075, -0.0323, 0.03006, 0.2042, -...
# 1       [0.09625, 0.0661, -0.1677, -0.07263, 0.313, 0....
# 2       [0.1614, -0.1062, -0.1567, -0.01685, 0.1838, -...
# 3       [0.2083, -0.2356, 0.1348, 0.172, 0.3887, -0.36...
# 4       [0.05188, -0.0868, -0.064, 0.072, 0.3145, -0.2...
# ...                                                   ...
# 422756  [0.1328, -0.08203, 0.2471, -0.08264, 0.0696, 0...
# 422757  [0.1157, 0.2744, 0.2466, -0.1272, 0.1846, -0.0...
# 422758  [0.1274, -0.2164, 0.0941, 0.33, 0.317, -0.1034...
# 422759  [0.0874, -0.1564, 0.09424, 0.1768, 0.284, 0.02...
# 422760  [-0.003784, -0.2306, 0.1538, 0.2285, 0.284, -0...
#
#                                         features_weighted  \
# 0       [0.1464, -0.03265, 0.0006714, 0.02676, 0.2542,...
# 1       [0.13, 0.01855, -0.10767, -0.0554, 0.341, 0.04...
# 2       [0.1821, -0.11926, -0.0989, -0.010765, 0.2378,...
# 3       [0.2196, -0.2228, 0.1343, 0.1403, 0.4019, -0.3...
# 4       [0.0945, -0.1037, -0.02472, 0.06033, 0.3423, -...
# ...                                                   ...
# 422756  [0.1466, -0.1256, 0.2288, -0.07556, 0.0916, -0...
# 422757  [0.1489, 0.2537, 0.2363, -0.1395, 0.2311, -0.0...
# 422758  [0.1405, -0.2322, 0.08954, 0.3428, 0.3093, -0....
# 422759  [0.10846, -0.1841, 0.0896, 0.22, 0.283, 0.0121...
# 422760  [0.03552, -0.2434, 0.1373, 0.2612, 0.283, -0.0...
#
#                                                    melody  \
# 0       (50, -1, 50, 50, 50, 50, 50, 50, 50, 50, 50, 5...
# 1       (-2, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 3...
# 2       (-2, -2, -2, -2, -2, -2, 57, 56, 56, 55, 55, -...
# 3       (67, 67, 67, 67, 67, 67, 67, 67, 67, 66, 66, -...
# 4       (-2, -2, 60, 60, -1, -2, -2, -2, 60, 60, 60, -...
# ...                                                   ...
# 422756  (-2, 66, 66, 59, 59, 59, 59, 59, 59, 59, 59, 5...
# 422757  (-2, -2, 69, 69, -1, 64, -1, -2, -2, 71, 71, 7...
# 422758  (63, 63, 60, 60, 63, 63, 63, 65, 65, 63, 62, 6...
# 422759  (50, -1, 50, 50, 50, 50, 50, 50, 50, 50, 50, 5...
# 422760  (-2, -2, -2, -2, -2, -2, 81, 81, 81, 81, 81, 8...
#
#                                         combined_features
# 0       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 1       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 2       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 3       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 4       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# ...                                                   ...
# 422756  [0.2013, -0.2996, 0.1554, -0.04733, 0.1796, -0...
# 422757  [0.282, 0.1711, 0.1952, -0.1887, 0.417, 0.0896...
# 422758  [0.1924, -0.2947, 0.07135, 0.392, 0.2793, -0.0...
# 422759  [0.1924, -0.2947, 0.07135, 0.392, 0.2793, -0.0...
# 422760  [0.1924, -0.2947, 0.07135, 0.392, 0.2793, -0.0...
#
# [422761 rows x 11 columns]

# %%
print('shape of combined features: ', combined_features.shape)
print('shape of features mean: ', features_mean.shape)
print('shape of features weighted: ', features_weighted.shape)

# Calculates the length of each Melody object _events
event_lengths = base_data['melody'].apply(lambda x: len(x._events))
# Check that all _events have the same length
unique_length_count = event_lengths.nunique()
# print the result
if unique_length_count == 1:
    print("All Melody obejcts have the same length of _events")
else:
    print(f"Exist different length of _events，there are {unique_length_count} kinds of lenegth")
# Out:
# shape of combined features:  (422761, 1024)
# shape of features mean:  (422761, 512)
# shape of features weighted:  (422761, 512)
# Exist different length of _events，there are 80 kinds of lenegth

# %%
# Calculates the length of each Melody object _events
max_length = base_data['melody'].apply(lambda x: len(x._events)).max()
# max_length is now the longest _events length in the entire dataset
print("The max length of events:", max_length)
# Out:
# The max length of events: 81

# %%
global_min_feature = base_data['features_mean'].apply(lambda x: np.min(x)).min()
global_max_feature = base_data['features_mean'].apply(lambda x: np.max(x)).max()

print('min: ', global_min_feature)
print('max: ', global_max_feature)
# Out:
# min:  -6.195
# max:  5.023

# %% [markdown]
# ## Create Data Generator

# %%
def normalize(data, min_val, max_val):
    normalized_data = 2 * (data - min_val) / (max_val - min_val) - 1
    return normalized_data

def denormalize(data, min_val, max_val):
    data = (data + 1) / 2 * (max_val - min_val) + min_val
    return data

# %%
def augment_data(features):
    augmented_features = []
    for feature in features:
        noise = np.random.normal(0, 0.1, feature.shape)
        augmented_features.append(feature + noise)
    return np.array(augmented_features)

# %%
def data_generator(df, feature_col, batch_size, max_length):
    num_batches = (len(df) + batch_size - 1) // batch_size

    for i in range(num_batches):
        batch_slice = slice(i * batch_size, min((i + 1) * batch_size, len(df)))
        batch = df.iloc[batch_slice]

        # Deal with melody
        melody_tensors = []
        for melody in batch['melody']:
            melody_events = melody._events
            melody_tensor = tf.convert_to_tensor(melody_events, dtype=tf.float32)
            melody_tensor = normalize(melody_tensor,-2, 127)
            # Calculate the number of fillers you need
            padding_needed = max_length - tf.shape(melody_tensor)[0]

            # Fill if padding_needed is greater than 0
            if padding_needed > 0:
                padded_melody_tensor = tf.pad(melody_tensor, [[0, padding_needed]], "CONSTANT")
            else:
                padded_melody_tensor = melody_tensor

            padded_melody_tensor = tf.expand_dims(padded_melody_tensor, -1)
            melody_tensors.append(padded_melody_tensor)

        features = np.array(batch[feature_col].tolist())
        augmented_features = augment_data(features)
        normalized_features = normalize(augmented_features, global_min_feature, global_max_feature)

        yield  (normalized_features, np.stack(melody_tensors)), np.stack(melody_tensors)

# %%
def created_dataset(df, features_col, batch_size, max_length):
    dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(df, features_col, batch_size, max_length),
    output_signature=(
        (tf.TensorSpec(shape=(None, np.stack(df[features_col].values).shape[1]), dtype=tf.float32),         # Adjust this as well
        tf.TensorSpec(shape=(None, max_length, 1), dtype=tf.float32)),  # Adjust the shape based on your actual data
        tf.TensorSpec(shape=(None, max_length, 1), dtype=tf.float32)
    )
)
    return dataset

# %% [markdown]
# ## Seperate the Dataset (Train data, Test data)

# %%
batch_size = 16
max_length = 81

dataset = created_dataset(base_data, 'features_mean', batch_size, max_length)

# Shuffle and seperate the dataset
dataset = dataset.shuffle(buffer_size=1000)
train_size = int(0.8 * sum(1 for _ in dataset))
train_dataset = dataset.take(train_size)
test_dataset = dataset.skip(train_size)

# Print out for verification
for (features, melodies), true_melodies in train_dataset.take(1):
    print("Train Melodies shape:", melodies.shape)
    print("Train Features shape:", features.shape)

for (features, melodies), true_melodies in test_dataset.take(1):
    print("Test Melodies shape:", melodies.shape)
    print("Test Features shape:", features.shape)
# Out:
# Train Melodies shape: (16, 81, 1)
# Train Features shape: (16, 512)
# Test Melodies shape: (16, 81, 1)
# Test Features shape: (16, 512)

# %%
# Print out for verification
for (features, melodies), true_melodies in train_dataset.take(1):
    print("Train Melodies shape:", melodies.numpy())
    print("Train Features shape:", features.numpy())
# Out:
# Train Melodies shape: [[[-1.        ]
#   [-1.        ]
#   [-1.        ]
#   ...
#   [ 0.        ]
#   [ 0.        ]
#   [ 0.        ]]
#
#  [[-0.19379842]
#   [-0.9844961 ]
#   [-0.19379842]
#   ...
#   [-0.25581396]
#   [-0.25581396]
#   [-0.25581396]]
#
#  [[-1.        ]
#   [-1.        ]
#   [-1.        ]
#   ...
#   [-1.        ]
#   [-1.        ]
#   [-0.22480619]]
#
#  ...
#
#  [[-0.19379842]
#   [-0.9844961 ]
#   [-0.19379842]
#   ...
#   [-0.25581396]
#   [-0.25581396]
#   [-0.25581396]]
#
#  [[-1.        ]
#   [-1.        ]
#   [-1.        ]
#   ...
#   [ 0.        ]
#   [ 0.        ]
#   [ 0.        ]]
#
#  [[-0.3488372 ]
#   [-0.3488372 ]
#   [-0.3488372 ]
#   ...
#   [ 0.        ]
#   [ 0.        ]
#   [ 0.        ]]]
# Train Features shape: [[0.15242228 0.14464085 0.05553046 ... 0.1282452  0.14766559 0.01617902]
#  [0.13257587 0.03964143 0.13566442 ... 0.06798123 0.11738124 0.05187224]
#  [0.12038718 0.04804555 0.1445355  ... 0.19282287 0.10998559 0.16423975]
#  ...
#  [0.12707384 0.06891587 0.13391772 ... 0.09619346 0.0451706  0.15143783]
#  [0.14674488 0.06315098 0.13833317 ... 0.13201322 0.07186668 0.15975183]
#  [0.15014444 0.15122925 0.10139805 ... 0.16436109 0.07390549 0.14929973]]

# %% [markdown]
# ## Generative Model (VAE)

# %% [markdown]
# For feature vectors extracted by CLIP model, we may not need too complex encoder network, because these features are already at a high level of abstraction. As a result, the encoder can be simpler to keep this encoded high-level information, while the decoder may need more tweaking to produce a more detailed output (such as a music sequence).

# %% [markdown]
# ### Sampling

# %% [markdown]
# The sampling function samples a potential vector from the normal distribution 𝑧 using the reparameterization trick. This function avoids the gradient propagation problem caused by random nodes and allows the model to be trained using backpropagation.

# %%
# Define the sampling function
def sampling(args):
    z_mean, z_log_sigma = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_sigma) * epsilon

# %% [markdown]
# ### Encoder

# %% [markdown]
# Since the input features are already highly abstract, encoders can be simplified or designed to be more focused on accommodating such high-dimensional features.
# The encoder maps the input data to the latent space, outputs the potential mean z_mean and the potential log-variance z_log_sigma, and uses the sampling function to generate the potential vector 𝑧.

# %%
def build_encoder(input_dim, latent_dim):
    inputs = Input(shape=(input_dim,))
    x = Dense(512)(inputs)
    x = ReLU()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = Dense(256)(x)
    x = ReLU()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = Dense(128)(x)
    x = ReLU()(x)
    x = BatchNormalization()(x)
    z_mean = Dense(latent_dim)(x)
    z_log_sigma = Dense(latent_dim)(x)

    z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_sigma])
    encoder = Model(inputs, [z_mean, z_log_sigma, z], name='encoder')
    encoder.summary()
    return encoder

# %% [markdown]
# ### Decoder

# %% [markdown]
# Learn how to generate concrete musical sequences from abstract features extracted from the latent space. Predict every note or event in Melody.

# %%
def build_decoder(latent_dim, output_dim):
    latent_inputs = Input(shape=(latent_dim,))

    # Fully connected layer
    x = Dense(256, activation='relu')(latent_inputs)
    x = BatchNormalization()(x)
    x = RepeatVector(output_dim)(x)  # Expand the latent vector across the sequence

    # LSTM layer
    x = LSTM(256, return_sequences=True)(x)
    x = LSTM(128, return_sequences=True)(x)

    # Convolution layer
    x = Conv1D(64, 3, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = Conv1D(32, 3, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)

    # Transposed Convolution
    x = Conv1DTranspose(16, 3, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = Conv1DTranspose(8, 3, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)

    outputs = TimeDistributed(Dense(1, activation='tanh'))(x)  # Output at each time step

    decoder = Model(latent_inputs, outputs, name='decoder')
    decoder.summary()
    return decoder

# %% [markdown]
# ### VAE Model

# %%
def reconstruction_loss(y_true, y_pred):
    mse_loss = K.mean(K.square(y_true - y_pred), axis=[1, 2])

    y_true_norm = K.l2_normalize(y_true, axis=1)
    y_pred_norm = K.l2_normalize(y_pred, axis=1)
    cosine_similarity = K.sum(y_true_norm * y_pred_norm, axis=2)

    cosine_loss = 1 - cosine_similarity

    combined_loss = 0.1 * mse_loss + 0.6 * K.mean(cosine_loss, axis=1)
    return combined_loss

def kl_loss(z_mean, z_log_sigma):
    kl_loss = -0.5 * K.sum(1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma), axis=-1)
    return kl_loss

def vae_loss(true_melody, reconstructed_melody, z_mean, z_log_sigma, beta = 0.1):
    recon_loss = reconstruction_loss(true_melody, reconstructed_melody)
    kl = kl_loss(z_mean, z_log_sigma)
    return recon_loss + kl * beta

# %%
class VAE(Model):
    def __init__(self, encoder, decoder, beta=0.1, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.beta = beta

    def call(self, inputs):
        inputs, true_melody = inputs
        z_mean, z_log_sigma, z = self.encoder(inputs)
        reconstructed_melody = self.decoder(z)
        recon_loss = reconstruction_loss(true_melody, reconstructed_melody)
        kl = kl_loss(z_mean, z_log_sigma)
        total_loss = recon_loss + self.beta * kl
        self.add_loss(total_loss)
        self.add_metric(recon_loss, name='reconstruction_loss', aggregation='mean')
        self.add_metric(kl, name='kl_loss', aggregation='mean')
        return reconstructed_melody

# %%
def build_vae_models(input_dim, sequence_length, latent_dim, beta=0.1):
    inputs = Input(shape=(input_dim,), name="input_features")
    true_melody = Input(shape=(sequence_length, 1), name="true_melody")

    encoder = build_encoder(input_dim, latent_dim)
    decoder = build_decoder(latent_dim, sequence_length)

    z_mean, z_log_sigma, z = encoder(inputs)
    reconstructed_melody = decoder(z)

    vae_train = VAE(encoder, decoder, beta)
    vae_train.compile(optimizer='adam')

    vae_predict = Model(inputs=inputs, outputs=reconstructed_melody, name='vae_predict')

    return vae_train, vae_predict

# %% [markdown]
# ## Train the Model

# %%
input_dim = 512
sequence_length = 81
latent_dim = 64

epochs = 4

vae_train, _ = build_vae_models(input_dim, sequence_length, latent_dim)
vae_train.fit(train_dataset, epochs=epochs, validation_data=test_dataset)
# Evaluate the model performancee
total_loss = vae_train.evaluate(test_dataset)
print("Test VAE Loss:", total_loss)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 512)]        0           []
#
#  dense_6 (Dense)                (None, 512)          262656      ['input_3[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 512)          0           ['dense_6[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 512)         2048        ['re_lu_3[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 512)          0           ['batch_normalization_4[0][0]']
#
#  dense_7 (Dense)                (None, 256)          131328      ['dropout_2[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 256)          0           ['dense_7[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 256)         1024        ['re_lu_4[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 256)          0           ['batch_normalization_5[0][0]']
#
#  dense_8 (Dense)                (None, 128)          32896       ['dropout_3[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 128)          0           ['dense_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 128)         512         ['re_lu_5[0][0]']
#  rmalization)
#
#  dense_9 (Dense)                (None, 64)           8256        ['batch_normalization_6[0][0]']
#
#  dense_10 (Dense)               (None, 64)           8256        ['batch_normalization_6[0][0]']
#
#  lambda_1 (Lambda)              (None, 64)           0           ['dense_9[0][0]',
#                                                                   'dense_10[0][0]']
#
# ==================================================================================================
# Total params: 446,976
# Trainable params: 445,184
# Non-trainable params: 1,792
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 64)]              0
#
#  dense_11 (Dense)            (None, 256)               16640
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  repeat_vector_1 (RepeatVect  (None, 81, 256)          0
#  or)
#
#  lstm_2 (LSTM)               (None, 81, 256)           525312
#
#  lstm_3 (LSTM)               (None, 81, 128)           197120
#
#  conv1d (Conv1D)             (None, 81, 64)            24640
#
#  batch_normalization_8 (Batc  (None, 81, 64)           256
#  hNormalization)
#
#  conv1d_1 (Conv1D)           (None, 81, 32)            6176
#
#  batch_normalization_9 (Batc  (None, 81, 32)           128
#  hNormalization)
#
#  conv1d_transpose (Conv1DTra  (None, 81, 16)           1552
#  nspose)
#
#  batch_normalization_10 (Bat  (None, 81, 16)           64
#  chNormalization)
#
#  conv1d_transpose_1 (Conv1DT  (None, 81, 8)            392
#  ranspose)
#
#  batch_normalization_11 (Bat  (None, 81, 8)            32
#  chNormalization)
#
#  time_distributed (TimeDistr  (None, 81, 1)            9
#  ibuted)
#
# =================================================================
# Total params: 773,345
# Trainable params: 772,593
# Non-trainable params: 752
# _________________________________________________________________
# Epoch 1/4
# 21138/21138 [==============================] - 967s 45ms/step - loss: 0.6413 - reconstruction_loss: 0.6127 - kl_loss: 0.2866 - val_loss: 0.6127 - val_reconstruction_loss: 0.6127 - val_kl_loss: 5.2093e-05
# Epoch 2/4
# 21138/21138 [==============================] - 933s 44ms/step - loss: 0.6125 - reconstruction_loss: 0.6124 - kl_loss: 0.0010 - val_loss: 0.6127 - val_reconstruction_loss: 0.6126 - val_kl_loss: 0.0011
# Epoch 3/4
# 21138/21138 [==============================] - 912s 43ms/step - loss: 0.6125 - reconstruction_loss: 0.6124 - kl_loss: 7.9173e-04 - val_loss: 0.6127 - val_reconstruction_loss: 0.6126 - val_kl_loss: 4.8992e-04
# Epoch 4/4
# 21138/21138 [==============================] - 923s 43ms/step - loss: 0.6125 - reconstruction_loss: 0.6124 - kl_loss: 0.0015 - val_loss: 0.6127 - val_reconstruction_loss: 0.6126 - val_kl_loss: 7.5170e-04
# 5285/5285 [==============================] - 304s 18ms/step - loss: 0.6127 - reconstruction_loss: 0.6126 - kl_loss: 7.5287e-04
# Test VAE Loss: [0.6126998662948608, 0.6126269102096558, 0.0007528665591962636]

# %%
# save the model
vae_train.save_weights('my models/my_vae_weights20.h5')

# %% [markdown]
# ## Load the Trained Model

# %%
# load the model
input_dim = 512
sequence_length = 81
latent_dim = 64

_ , model = build_vae_models(input_dim, sequence_length, latent_dim)
# load weights
model.load_weights('my models/my_vae_weights20.h5')
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 512)]        0           []
#
#  dense_13 (Dense)               (None, 512)          262656      ['input_5[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 512)          0           ['dense_13[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 512)         2048        ['re_lu_6[0][0]']
#  ormalization)
#
#  dropout_4 (Dropout)            (None, 512)          0           ['batch_normalization_12[0][0]']
#
#  dense_14 (Dense)               (None, 256)          131328      ['dropout_4[0][0]']
#
#  re_lu_7 (ReLU)                 (None, 256)          0           ['dense_14[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 256)         1024        ['re_lu_7[0][0]']
#  ormalization)
#
#  dropout_5 (Dropout)            (None, 256)          0           ['batch_normalization_13[0][0]']
#
#  dense_15 (Dense)               (None, 128)          32896       ['dropout_5[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 128)          0           ['dense_15[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 128)         512         ['re_lu_8[0][0]']
#  ormalization)
#
#  dense_16 (Dense)               (None, 64)           8256        ['batch_normalization_14[0][0]']
#
#  dense_17 (Dense)               (None, 64)           8256        ['batch_normalization_14[0][0]']
#
#  lambda_2 (Lambda)              (None, 64)           0           ['dense_16[0][0]',
#                                                                   'dense_17[0][0]']
#
# ==================================================================================================
# Total params: 446,976
# Trainable params: 445,184
# Non-trainable params: 1,792
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 64)]              0
#
#  dense_18 (Dense)            (None, 256)               16640
#
#  batch_normalization_15 (Bat  (None, 256)              1024
#  chNormalization)
#
#  repeat_vector_2 (RepeatVect  (None, 81, 256)          0
#  or)
#
#  lstm_4 (LSTM)               (None, 81, 256)           525312
#
#  lstm_5 (LSTM)               (None, 81, 128)           197120
#
#  conv1d_2 (Conv1D)           (None, 81, 64)            24640
#
#  batch_normalization_16 (Bat  (None, 81, 64)           256
#  chNormalization)
#
#  conv1d_3 (Conv1D)           (None, 81, 32)            6176
#
#  batch_normalization_17 (Bat  (None, 81, 32)           128
#  chNormalization)
#
#  conv1d_transpose_2 (Conv1DT  (None, 81, 16)           1552
#  ranspose)
#
#  batch_normalization_18 (Bat  (None, 81, 16)           64
#  chNormalization)
#
#  conv1d_transpose_3 (Conv1DT  (None, 81, 8)            392
#  ranspose)
#
#  batch_normalization_19 (Bat  (None, 81, 8)            32
#  chNormalization)
#
#  time_distributed_1 (TimeDis  (None, 81, 1)            9
#  tributed)
#
# =================================================================
# Total params: 773,345
# Trainable params: 772,593
# Non-trainable params: 752
# _________________________________________________________________

# %% [markdown]
# ## Test the Model

# %% [markdown]
# ### Load the Test Data

# %%
# image_add = "E:\\Project and Dissertation in Data Science\\dataset\\dataset\\test\\ivan-aivazovsky_sea-at-night-1861.jpg"
# image_add = "E:\\Project and Dissertation in Data Science\\dataset\\artemis_official_data\\art_images\\vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890.jpg"
text = "The steep mountains and the moonlight provide safety to the inhabitants of the isolated towns. "
# text = "I can imagine the sailors resting this peaceful night, dreaming of new adventures "
text = "She seems very happy in the picture, and you want to know what what is behind the smile. "

# %% [markdown]
# ### Extract Text-Image Features (CLIP Model)

# %%
# load pre-trained CLIP model
device = "cuda" if torch.cuda.is_available() else "cpu"
extracted_features_model, preprocess = clip.load("ViT-B/32", device=device)

# %%
# extract the images and text features
with torch.no_grad():
    image = Image.open(image_add).convert("RGB")
    image = preprocess(image).unsqueeze(0)
    # image feature
    image_feature = torch.cat([extracted_features_model.encode_image(image.to(device))]).cpu().numpy()

    # text feature
    text_tokens = clip.tokenize(text).to(device)
    text_feature = extracted_features_model.encode_text(text_tokens).cpu().numpy()

print('image features: ', image_feature.shape)
print('text features: ', text_feature.shape)
#    0.14718552 -0.00842437  0.13208449  0.20445996  0.09763166  0.06038426
#    0.05400378  0.08866494  0.12109362  0.03055324  0.09175946  0.12102696
#    0.12545302  0.14925947  0.10214823  0.05423455  0.16139409  0.14601318
#    0.07871594  0.06403593  0.15479454  0.13966228  0.0876161   0.09099183
#    0.12572882  0.08508939  0.09141222  0.12331999  0.15564356  0.11185833
#    0.1052701   0.16169266]]

# %% [markdown]
# ### Prediction

# %%
# generate the Melody by model
predicted_melody = model.predict(augmented_features)

print(predicted_melody)
print(predicted_melody.shape)
# Out:
# 1/1 [==============================] - 0s 14ms/step
# [[[-0.7047028 ]
#   [-0.6356874 ]
#   [-0.51186   ]
#   [-0.48547757]
#   [-0.5456437 ]
#   [-0.46289298]
#   [-0.4123169 ]
#   [-0.38186106]
#   [-0.3668536 ]
#   [-0.35966998]
#   [-0.35705122]
#   [-0.35048485]
#   [-0.34449646]
#   [-0.34089324]
#   [-0.33974797]
#   [-0.33951923]
#   [-0.33810374]
#   [-0.3363762 ]
#   [-0.33647424]
#   [-0.33527735]
#   [-0.3337405 ]
#   [-0.3324287 ]
#   [-0.33245537]
#   [-0.3322619 ]
#   [-0.3312198 ]
#   [-0.3303257 ]
#   [-0.32839352]
#   [-0.3256026 ]
#   [-0.32559463]
#   [-0.3258566 ]
#   [-0.32505238]
#   [-0.32427475]
#   [-0.3237698 ]
#   [-0.32320097]
#   [-0.32250255]
#   [-0.32209286]
#   [-0.32199112]
#   [-0.32236275]
#   [-0.32289156]
#   [-0.3224581 ]
#   [-0.32151324]
#   [-0.32028937]
#   [-0.31864116]
#   [-0.31499085]
#   [-0.31312767]
#   [-0.31059945]
#   [-0.3090008 ]
#   [-0.30816296]
#   [-0.30659148]
#   [-0.30425394]
#   [-0.30270442]
#   [-0.3012004 ]
#   [-0.29976398]
#   [-0.298381  ]
#   [-0.29639697]
#   [-0.29420748]
#   [-0.29209298]
#   [-0.29041588]
#   [-0.28965256]
#   [-0.28890833]
#   [-0.28818458]
#   [-0.28749254]
#   [-0.28658766]
#   [-0.28569   ]
#   [-0.28515652]
#   [-0.28459796]
#   [-0.2841466 ]
#   [-0.28368172]
#   [-0.2832409 ]
#   [-0.2827258 ]
#   [-0.2822057 ]
#   [-0.28170452]
#   [-0.2812234 ]
#   [-0.28076398]
#   [-0.2803213 ]
#   [-0.27989545]
#   [-0.2794818 ]
#   [-0.27717543]
#   [-0.2305555 ]
#   [-0.10545484]
#   [-0.08493272]]]
# (1, 81, 1)

# %%
predicted_melody = denormalize(predicted_melody, -2, 127)

print(predicted_melody)
print(predicted_melody.shape)
# Out:
# [[[17.046669]
#   [21.498161]
#   [29.48503 ]
#   [31.186695]
#   [27.305983]
#   [32.643402]
#   [35.90556 ]
#   [37.86996 ]
#   [38.837944]
#   [39.301285]
#   [39.470196]
#   [39.893726]
#   [40.279976]
#   [40.512383]
#   [40.586258]
#   [40.60101 ]
#   [40.692307]
#   [40.803734]
#   [40.797413]
#   [40.874615]
#   [40.97374 ]
#   [41.05835 ]
#   [41.056625]
#   [41.069107]
#   [41.136322]
#   [41.193993]
#   [41.31862 ]
#   [41.498634]
#   [41.499146]
#   [41.48225 ]
#   [41.534122]
#   [41.58428 ]
#   [41.616848]
#   [41.653538]
#   [41.698586]
#   [41.72501 ]
#   [41.731575]
#   [41.7076  ]
#   [41.673492]
#   [41.701454]
#   [41.762398]
#   [41.841335]
#   [41.947643]
#   [42.18309 ]
#   [42.30327 ]
#   [42.466335]
#   [42.56945 ]
#   [42.62349 ]
#   [42.724846]
#   [42.87562 ]
#   [42.975563]
#   [43.072575]
#   [43.165222]
#   [43.25443 ]
#   [43.382397]
#   [43.52362 ]
#   [43.660004]
#   [43.768177]
#   [43.81741 ]
#   [43.86541 ]
#   [43.912094]
#   [43.956734]
#   [44.015095]
#   [44.072994]
#   [44.107407]
#   [44.14343 ]
#   [44.172543]
#   [44.202526]
#   [44.23096 ]
#   [44.264187]
#   [44.297733]
#   [44.330055]
#   [44.361088]
#   [44.390724]
#   [44.419277]
#   [44.446747]
#   [44.473427]
#   [44.622185]
#   [47.62917 ]
#   [55.698162]
#   [57.02184 ]]]
# (1, 81, 1)

# %%
predicted_notes = np.round(predicted_melody).astype(int)
print(predicted_notes)
# Out:
# [[[17]
#   [21]
#   [29]
#   [31]
#   [27]
#   [33]
#   [36]
#   [38]
#   [39]
#   [39]
#   [39]
#   [40]
#   [40]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [41]
#   [42]
#   [42]
#   [42]
#   [42]
#   [42]
#   [42]
#   [42]
#   [42]
#   [42]
#   [42]
#   [42]
#   [42]
#   [42]
#   [42]
#   [42]
#   [42]
#   [43]
#   [43]
#   [43]
#   [43]
#   [43]
#   [43]
#   [43]
#   [43]
#   [43]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [44]
#   [45]
#   [48]
#   [56]
#   [57]]]

# %%
melody = note_seq.Melody(predicted_notes.flatten().tolist())
melody

# %%
melody._events
# Out:
# [17,
#  21,
#  29,
#  31,
#  27,
#  33,
#  36,
#  38,
#  39,
#  39,
#  39,
#  40,
#  40,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  41,
#  42,
#  42,
#  42,
#  42,
#  42,
#  42,
#  42,
#  42,
#  42,
#  42,
#  42,
#  42,
#  42,
#  42,
#  42,
#  42,
#  43,
#  43,
#  43,
#  43,
#  43,
#  43,
#  43,
#  43,
#  43,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  44,
#  45,
#  48,
#  56,
#  57]

# %% [markdown]
# ## Sentiment Analysis text content: Calculate the range of QPM

# %%
positive_words = set(opinion_lexicon.positive())
negative_words = set(opinion_lexicon.negative())

calm_words = {
    'peaceful', 'calm', 'relaxed', 'serene', 'tranquil', 'composed', 'quiet', 'soothing',
    'content', 'easygoing', 'gentle', 'harmonious', 'placid', 'mellow', 'restful',
    'untroubled', 'cool', 'collected'
}
excited_words = {
    'excited', 'energetic', 'lively', 'thrilled', 'exhilarated', 'animated', 'enthusiastic',
    'vivacious', 'vibrant', 'spirited', 'eager', 'dynamic', 'passionate', 'zealous',
    'high-spirited', 'raring', 'buoyant', 'stimulated'
}

def sentiment_analysis(text):

    words = word_tokenize(text.lower())

    num_positive_words = sum(1 for word in words if word in positive_words)
    num_negative_words = sum(1 for word in words if word in negative_words)
    num_neutral_words = len(words) - num_positive_words - num_negative_words
    num_calm_words = sum(1 for word in words if word in calm_words)
    num_excited_words = sum(1 for word in words if word in excited_words)

    total_words = num_positive_words + num_negative_words + num_neutral_words
    sentiment_score = ((num_positive_words - num_negative_words) + num_neutral_words * 0.5) / max(1, total_words)

    total_emotion_words = num_calm_words + num_excited_words + num_neutral_words
    excitement_score = ((num_excited_words - num_calm_words) + num_neutral_words * 0.5) / max(1, total_emotion_words)

    return sentiment_score, excitement_score

def sentiment_to_qpm(sentiment, excitement):
    if excitement >= 0.5:
        if sentiment >= 0.5:
            return 60, 70
        elif sentiment > -0.5:
            return 40, 60
        else:
            return 30, 40
    else:
        if sentiment >= 0.5:
            return 20, 30
        elif sentiment > -0.5:
            return 10, 20
        else:
            return 5, 10

sentiment_score, excitement_score = sentiment_analysis(text)
print('Sentiment Score:', sentiment_score)
print('Excitement Score:', excitement_score)

qpm_range = sentiment_to_qpm(sentiment_score, excitement_score)
print('QPM Range:', qpm_range)

random_qpm = random.randint(qpm_range[0], qpm_range[1])
print('Random QPM:', random_qpm)
# Out:
# Sentiment Score: 0.55
# Excitement Score: 0.5
# QPM Range: (60, 70)
# Random QPM: 64

# %%
note_sequence = melody.to_sequence(velocity=100, instrument=0, program=0, sequence_start_time=0.0, qpm=67)

time_signature = note_sequence.time_signatures.add()
time_signature.time = 0
time_signature.numerator = 4
time_signature.denominator = 4

print(note_sequence)
# Out:
# ticks_per_quarter: 220
# time_signatures {
#   numerator: 4
#   denominator: 4
# }
# tempos {
#   qpm: 67.0
# }
# notes {
#   pitch: 17
#   velocity: 100
#   end_time: 0.22388059701492538
# }
# notes {
#   pitch: 21
#   velocity: 100
#   start_time: 0.22388059701492538
#   end_time: 0.44776119402985076
# }
# notes {
#   pitch: 29
#   velocity: 100
#   start_time: 0.44776119402985076
#   end_time: 0.6716417910447762
# }
# notes {
#   pitch: 31
#   velocity: 100
#   start_time: 0.6716417910447762
#   end_time: 0.8955223880597015
# }
# notes {
#   pitch: 27
#   velocity: 100
#   start_time: 0.8955223880597015
#   end_time: 1.119402985074627
# }
# notes {
#   pitch: 33
#   velocity: 100
#   start_time: 1.119402985074627
#   end_time: 1.3432835820895523
# }
# notes {
#   pitch: 36
#   velocity: 100
#   start_time: 1.3432835820895523
#   end_time: 1.5671641791044777
# }
# notes {
#   pitch: 38
#   velocity: 100
#   start_time: 1.5671641791044777
#   end_time: 1.791044776119403
# }
# notes {
#   pitch: 39
#   velocity: 100
#   start_time: 1.791044776119403
#   end_time: 2.0149253731343286
# }
# notes {
#   pitch: 39
#   velocity: 100
#   start_time: 2.0149253731343286
#   end_time: 2.238805970149254
# }
# notes {
#   pitch: 39
#   velocity: 100
#   start_time: 2.238805970149254
#   end_time: 2.4626865671641793
# }
# notes {
#   pitch: 40
#   velocity: 100
#   start_time: 2.4626865671641793
#   end_time: 2.6865671641791047
# }
# notes {
#   pitch: 40
#   velocity: 100
#   start_time: 2.6865671641791047
#   end_time: 2.91044776119403
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 2.91044776119403
#   end_time: 3.1343283582089554
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 3.1343283582089554
#   end_time: 3.3582089552238807
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 3.3582089552238807
#   end_time: 3.582089552238806
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 3.582089552238806
#   end_time: 3.8059701492537314
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 3.8059701492537314
#   end_time: 4.029850746268657
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 4.029850746268657
#   end_time: 4.253731343283582
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 4.253731343283582
#   end_time: 4.477611940298508
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 4.477611940298508
#   end_time: 4.701492537313433
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 4.701492537313433
#   end_time: 4.925373134328359
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 4.925373134328359
#   end_time: 5.149253731343284
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 5.149253731343284
#   end_time: 5.373134328358209
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 5.373134328358209
#   end_time: 5.597014925373134
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 5.597014925373134
#   end_time: 5.82089552238806
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 5.82089552238806
#   end_time: 6.044776119402985
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 6.044776119402985
#   end_time: 6.268656716417911
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 6.268656716417911
#   end_time: 6.492537313432836
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 6.492537313432836
#   end_time: 6.7164179104477615
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 6.7164179104477615
#   end_time: 6.940298507462686
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 6.940298507462686
#   end_time: 7.164179104477612
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 7.164179104477612
#   end_time: 7.388059701492538
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 7.388059701492538
#   end_time: 7.611940298507463
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 7.611940298507463
#   end_time: 7.835820895522389
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 7.835820895522389
#   end_time: 8.059701492537314
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 8.059701492537314
#   end_time: 8.283582089552239
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 8.283582089552239
#   end_time: 8.507462686567164
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 8.507462686567164
#   end_time: 8.73134328358209
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 8.73134328358209
#   end_time: 8.955223880597016
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 8.955223880597016
#   end_time: 9.17910447761194
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 9.17910447761194
#   end_time: 9.402985074626866
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 9.402985074626866
#   end_time: 9.626865671641792
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 9.626865671641792
#   end_time: 9.850746268656717
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 9.850746268656717
#   end_time: 10.074626865671641
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 10.074626865671641
#   end_time: 10.298507462686567
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 10.298507462686567
#   end_time: 10.522388059701493
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 10.522388059701493
#   end_time: 10.746268656716419
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 10.746268656716419
#   end_time: 10.970149253731345
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 10.970149253731345
#   end_time: 11.194029850746269
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 11.194029850746269
#   end_time: 11.417910447761194
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 11.417910447761194
#   end_time: 11.64179104477612
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 11.64179104477612
#   end_time: 11.865671641791046
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 11.865671641791046
#   end_time: 12.08955223880597
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 12.08955223880597
#   end_time: 12.313432835820896
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 12.313432835820896
#   end_time: 12.537313432835822
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 12.537313432835822
#   end_time: 12.761194029850747
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 12.761194029850747
#   end_time: 12.985074626865671
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 12.985074626865671
#   end_time: 13.208955223880597
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 13.208955223880597
#   end_time: 13.432835820895523
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 13.432835820895523
#   end_time: 13.656716417910449
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 13.656716417910449
#   end_time: 13.880597014925373
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 13.880597014925373
#   end_time: 14.104477611940299
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 14.104477611940299
#   end_time: 14.328358208955224
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 14.328358208955224
#   end_time: 14.55223880597015
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 14.55223880597015
#   end_time: 14.776119402985076
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 14.776119402985076
#   end_time: 15.0
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 15.0
#   end_time: 15.223880597014926
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 15.223880597014926
#   end_time: 15.447761194029852
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 15.447761194029852
#   end_time: 15.671641791044777
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 15.671641791044777
#   end_time: 15.895522388059701
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 15.895522388059701
#   end_time: 16.11940298507463
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 16.11940298507463
#   end_time: 16.34328358208955
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 16.34328358208955
#   end_time: 16.567164179104477
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 16.567164179104477
#   end_time: 16.791044776119403
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 16.791044776119403
#   end_time: 17.01492537313433
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 17.01492537313433
#   end_time: 17.238805970149254
# }
# notes {
#   pitch: 45
#   velocity: 100
#   start_time: 17.238805970149254
#   end_time: 17.46268656716418
# }
# notes {
#   pitch: 48
#   velocity: 100
#   start_time: 17.46268656716418
#   end_time: 17.686567164179106
# }
# notes {
#   pitch: 56
#   velocity: 100
#   start_time: 17.686567164179106
#   end_time: 17.910447761194032
# }
# notes {
#   pitch: 57
#   velocity: 100
#   start_time: 17.910447761194032
#   end_time: 18.134328358208958
# }
# total_time: 18.134328358208958

# %%
# Use FluidSynth to generate audio data
# Need to specify the SoundFont file path
# audio_samples = note_seq.fluidsynth(ns, sample_rate=44100, sf2_path='GeneralUser GS v1.471.sf2')
# audio_samples = note_seq.fluidsynth(ns, sample_rate=44100, sf2_path="TimGM6mb.sf2")
audio_samples = note_seq.fluidsynth(note_sequence, sample_rate=48000, sf2_path="FluidR3Mono_GM.sf3")

# Save audio data as WAV file
# 'audio_samples' is a floating-point audio array generated by fluidsynth
# Normalize audio and convert to 16-bit PCM format
write('generated_audios/output_audio_m14_3.wav', 48000, np.int16(audio_samples / np.max(np.abs(audio_samples)) * 32767))
