# %% [markdown]
# # Model Orion

# %% [markdown]
# Attention Mechanism: Introducing an attention mechanism into the decoder can help the model pay more attention to a specific part of the input at each time step, rather than relying only on information from the previous state. This increases the variety of the output, especially at the beginning of the sequence.

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import librosa
from note_seq.protobuf import music_pb2
from note_seq.midi_synth import fluidsynth
from note_seq import sequences_lib
from note_seq import audio_io
from note_seq import midi_io
from pydub import AudioSegment
import tensorflow as tf
from note_seq import note_sequence_to_midi_file, NoteSequence, midi_to_note_sequence
from magenta.models.music_vae import TrainedModel, configs

import pandas as pd
import torch
import clip
from PIL import Image
import os
from sklearn.metrics.pairwise import cosine_similarity

import torch
import torch.nn as nn
import note_seq

from tensorflow.keras.layers import Input, Dense, Lambda, LSTM, RNN, LSTMCell, RepeatVector, TimeDistributed, Layer, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras import Model
from tensorflow.keras import backend as K

from sklearn.model_selection import train_test_split

from tensorflow.keras.optimizers import Adam, SGD
from tqdm import tqdm

import h5py
import json

from tensorflow.keras.models import load_model
from scipy.io.wavfile import write
import fluidsynth

from nltk.corpus import opinion_lexicon
from nltk.tokenize import word_tokenize
import random

# %% [markdown]
# ## Load Dataset

# %%
# Load processed matched musical data, which has deleted the no-sound audio row of data
base_data = pd.read_csv("processed_music_matched_data.csv")
base_data
# Out:
#                                                   Artwork  \
# 0       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 1       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 2       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 3       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 4       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# ...                                                   ...
# 422756                          david-burliuk_landscape-1
# 422757                           gino-severini_a-dancer-1
# 422758                  ivan-aivazovsky_sea-at-night-1861
# 422759                  ivan-aivazovsky_sea-at-night-1861
# 422760                  ivan-aivazovsky_sea-at-night-1861
#
#                                             Art_Utterance  \
# 0       She seems very happy in the picture, and you w...
# 1       This woman has really knotty hands which makes...
# 2       When looking at this woman, I am filled with c...
# 3       A woman looking at ease, peaceful, and satisfi...
# 4       She looks like a lady from that past that migh...
# ...                                                   ...
# 422756  The greenery landscape and flowery background ...
# 422757  the collection and collage of different colors...
# 422758  The peaceful reflections of the moonlight on t...
# 422759  I can imagine the sailors resting this peacefu...
# 422760  The steep mountains and the moonlight provide ...
#
#                  Music_Name  \
# 0         ABVYSaLu_VM_10-20
# 1       vnwKpQeza3A_320-330
# 2         0VwX92X3iPc_30-40
# 3       kh6rmFg3U4k_480-490
# 4       -VI2IRq17rs_360-370
# ...                     ...
# 422756     M0ygCD6WyXw_0-10
# 422757     oMZcsGUi8ZE_0-10
# 422758    s1QeDT7jqHQ_30-40
# 422759    ABVYSaLu_VM_10-20
# 422760    8q0An6WY7_c_10-20
#
#                                             Music_Comment  Similarity_Score
# 0       Here we have a slow piano piece played in a ma...          0.791458
# 1       This is a recording of two didgeridoos. They a...          0.772168
# 2       This audio contains a female voice speaking in...          0.798202
# 3       The low quality recording features a resonatin...          0.792188
# 4       In this clip, a large bell is rung and left to...          0.740201
# ...                                                   ...               ...
# 422756  This clip consists of a blowing horn being pla...          0.758374
# 422757  This clip features a synchronised playing of s...          0.799300
# 422758  The low quality recording features multiple la...          0.781008
# 422759  Here we have a slow piano piece played in a ma...          0.733153
# 422760  The low quality recording features a theremin ...          0.761976
#
# [422761 rows x 5 columns]

# %% [markdown]
# ### Load Dataset with Extracted Features

# %%
# load HDF5 file
with h5py.File('processed_data_with_melody2.h5', 'r') as hf:
    melody_data = hf['melody'][:]
    # Deserialize the JSON string to the Melody object
    melodies = [note_seq.Melody(json.loads(m.decode())) for m in melody_data]

    image_features = hf['image_features'][:]
    text_features = hf['text_features'][:]
    features_mean = hf['features_mean'][:]
    features_weighted = hf['features_weighted'][:]
    combined_features = hf['combined_features'][:]

# Convert the array to a list and add it to other_data DataFrame
base_data['image_features'] = list(image_features)
base_data['text_features'] = list(text_features)
base_data['features_mean'] = list(features_mean)
base_data['features_weighted'] = list(features_weighted)
base_data['melody'] = list(melodies)
base_data['combined_features'] = list(combined_features)

# %%
base_data
# Out:
#                                                   Artwork  \
# 0       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 1       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 2       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 3       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 4       vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# ...                                                   ...
# 422756                          david-burliuk_landscape-1
# 422757                           gino-severini_a-dancer-1
# 422758                  ivan-aivazovsky_sea-at-night-1861
# 422759                  ivan-aivazovsky_sea-at-night-1861
# 422760                  ivan-aivazovsky_sea-at-night-1861
#
#                                             Art_Utterance  \
# 0       She seems very happy in the picture, and you w...
# 1       This woman has really knotty hands which makes...
# 2       When looking at this woman, I am filled with c...
# 3       A woman looking at ease, peaceful, and satisfi...
# 4       She looks like a lady from that past that migh...
# ...                                                   ...
# 422756  The greenery landscape and flowery background ...
# 422757  the collection and collage of different colors...
# 422758  The peaceful reflections of the moonlight on t...
# 422759  I can imagine the sailors resting this peacefu...
# 422760  The steep mountains and the moonlight provide ...
#
#                  Music_Name  \
# 0         ABVYSaLu_VM_10-20
# 1       vnwKpQeza3A_320-330
# 2         0VwX92X3iPc_30-40
# 3       kh6rmFg3U4k_480-490
# 4       -VI2IRq17rs_360-370
# ...                     ...
# 422756     M0ygCD6WyXw_0-10
# 422757     oMZcsGUi8ZE_0-10
# 422758    s1QeDT7jqHQ_30-40
# 422759    ABVYSaLu_VM_10-20
# 422760    8q0An6WY7_c_10-20
#
#                                             Music_Comment  Similarity_Score  \
# 0       Here we have a slow piano piece played in a ma...          0.791458
# 1       This is a recording of two didgeridoos. They a...          0.772168
# 2       This audio contains a female voice speaking in...          0.798202
# 3       The low quality recording features a resonatin...          0.792188
# 4       In this clip, a large bell is rung and left to...          0.740201
# ...                                                   ...               ...
# 422756  This clip consists of a blowing horn being pla...          0.758374
# 422757  This clip features a synchronised playing of s...          0.799300
# 422758  The low quality recording features multiple la...          0.781008
# 422759  Here we have a slow piano piece played in a ma...          0.733153
# 422760  The low quality recording features a theremin ...          0.761976
#
#                                            image_features  \
# 0       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 1       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 2       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 3       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 4       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# ...                                                   ...
# 422756  [0.2013, -0.2996, 0.1554, -0.04733, 0.1796, -0...
# 422757  [0.282, 0.1711, 0.1952, -0.1887, 0.417, 0.0896...
# 422758  [0.1924, -0.2947, 0.07135, 0.392, 0.2793, -0.0...
# 422759  [0.1924, -0.2947, 0.07135, 0.392, 0.2793, -0.0...
# 422760  [0.1924, -0.2947, 0.07135, 0.392, 0.2793, -0.0...
#
#                                             text_features  \
# 0       [-0.0315, 0.1757, -0.1968, 0.0465, -0.04526, -...
# 1       [-0.0724, 0.3037, -0.4678, -0.1588, 0.1721, 0....
# 2       [0.05783, -0.0409, -0.4458, -0.0473, -0.08594,...
# 3       [0.1517, -0.2998, 0.1375, 0.3303, 0.3237, -0.5...
# 4       [-0.1611, -0.002035, -0.2603, 0.1305, 0.1753, ...
# ...                                                   ...
# 422756  [0.06445, 0.1355, 0.3389, -0.1179, -0.04034, 0...
# 422757  [-0.05054, 0.3774, 0.2979, -0.06555, -0.04782,...
# 422758  [0.0625, -0.1382, 0.1168, 0.2683, 0.3545, -0.1...
# 422759  [-0.01753, -0.018, 0.11707, -0.0385, 0.2886, 0...
# 422760  [-0.2, -0.1665, 0.2362, 0.0648, 0.2886, 0.0142...
#
#                                             features_mean  \
# 0       [0.1167, 0.002075, -0.0323, 0.03006, 0.2042, -...
# 1       [0.09625, 0.0661, -0.1677, -0.07263, 0.313, 0....
# 2       [0.1614, -0.1062, -0.1567, -0.01685, 0.1838, -...
# 3       [0.2083, -0.2356, 0.1348, 0.172, 0.3887, -0.36...
# 4       [0.05188, -0.0868, -0.064, 0.072, 0.3145, -0.2...
# ...                                                   ...
# 422756  [0.1328, -0.08203, 0.2471, -0.08264, 0.0696, 0...
# 422757  [0.1157, 0.2744, 0.2466, -0.1272, 0.1846, -0.0...
# 422758  [0.1274, -0.2164, 0.0941, 0.33, 0.317, -0.1034...
# 422759  [0.0874, -0.1564, 0.09424, 0.1768, 0.284, 0.02...
# 422760  [-0.003784, -0.2306, 0.1538, 0.2285, 0.284, -0...
#
#                                         features_weighted  \
# 0       [0.1464, -0.03265, 0.0006714, 0.02676, 0.2542,...
# 1       [0.13, 0.01855, -0.10767, -0.0554, 0.341, 0.04...
# 2       [0.1821, -0.11926, -0.0989, -0.010765, 0.2378,...
# 3       [0.2196, -0.2228, 0.1343, 0.1403, 0.4019, -0.3...
# 4       [0.0945, -0.1037, -0.02472, 0.06033, 0.3423, -...
# ...                                                   ...
# 422756  [0.1466, -0.1256, 0.2288, -0.07556, 0.0916, -0...
# 422757  [0.1489, 0.2537, 0.2363, -0.1395, 0.2311, -0.0...
# 422758  [0.1405, -0.2322, 0.08954, 0.3428, 0.3093, -0....
# 422759  [0.10846, -0.1841, 0.0896, 0.22, 0.283, 0.0121...
# 422760  [0.03552, -0.2434, 0.1373, 0.2612, 0.283, -0.0...
#
#                                                    melody  \
# 0       (50, -1, 50, 50, 50, 50, 50, 50, 50, 50, 50, 5...
# 1       (-2, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 3...
# 2       (-2, -2, -2, -2, -2, -2, 57, 56, 56, 55, 55, -...
# 3       (67, 67, 67, 67, 67, 67, 67, 67, 67, 66, 66, -...
# 4       (-2, -2, 60, 60, -1, -2, -2, -2, 60, 60, 60, -...
# ...                                                   ...
# 422756  (-2, 66, 66, 59, 59, 59, 59, 59, 59, 59, 59, 5...
# 422757  (-2, -2, 69, 69, -1, 64, -1, -2, -2, 71, 71, 7...
# 422758  (63, 63, 60, 60, 63, 63, 63, 65, 65, 63, 62, 6...
# 422759  (50, -1, 50, 50, 50, 50, 50, 50, 50, 50, 50, 5...
# 422760  (-2, -2, -2, -2, -2, -2, 81, 81, 81, 81, 81, 8...
#
#                                         combined_features
# 0       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 1       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 2       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 3       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# 4       [0.265, -0.1715, 0.1322, 0.013596, 0.4536, -0....
# ...                                                   ...
# 422756  [0.2013, -0.2996, 0.1554, -0.04733, 0.1796, -0...
# 422757  [0.282, 0.1711, 0.1952, -0.1887, 0.417, 0.0896...
# 422758  [0.1924, -0.2947, 0.07135, 0.392, 0.2793, -0.0...
# 422759  [0.1924, -0.2947, 0.07135, 0.392, 0.2793, -0.0...
# 422760  [0.1924, -0.2947, 0.07135, 0.392, 0.2793, -0.0...
#
# [422761 rows x 11 columns]

# %%
print('shape of combined features: ', combined_features.shape)
print('shape of features mean: ', features_mean.shape)
print('shape of features weighted: ', features_weighted.shape)

# Calculates the length of each Melody object _events
event_lengths = base_data['melody'].apply(lambda x: len(x._events))
# Check that all _events have the same length
unique_length_count = event_lengths.nunique()
# print the result
if unique_length_count == 1:
    print("All Melody obejcts have the same length of _events")
else:
    print(f"Exist different length of _events，there are {unique_length_count} kinds of lenegth")
# Out:
# shape of combined features:  (422761, 1024)
# shape of features mean:  (422761, 512)
# shape of features weighted:  (422761, 512)
# Exist different length of _events，there are 80 kinds of lenegth

# %% [markdown]
# ## Create Data Generator

# %%
# Calculates the length of each Melody object _events
max_length = base_data['melody'].apply(lambda x: len(x._events)).max()
# max_length is now the longest _events length in the entire dataset
print("The max length of events:", max_length)
# Out:
# The max length of events: 81

# %%
# Calculate the global minimum and maximum values of the feature data
global_min_feature = base_data['features_mean'].apply(lambda x: np.min(x)).min()
global_max_feature = base_data['features_mean'].apply(lambda x: np.max(x)).max()

print('min: ', global_min_feature)
print('max: ', global_max_feature)
# Out:
# min:  -6.195
# max:  5.023

# %%
def normalize(data, min_val, max_val):
    normalized_data = 2 * (data - min_val) / (max_val - min_val) - 1
    return normalized_data

def denormalize(data, min_val, max_val):
    data = (data + 1) / 2 * (max_val - min_val) + min_val
    return data

# %%
# augment data function
def augment_data(features):
    augmented_features = []
    for feature in features:
        noise = np.random.normal(0, 0.1, feature.shape)  # Increase the noise amplitude to 0.1
        augmented_features.append(feature + noise)
    return np.array(augmented_features)

# %%
def data_generator(df, feature_col, batch_size, max_length):
    num_batches = (len(df) + batch_size - 1) // batch_size

    for i in range(num_batches):
        batch_slice = slice(i * batch_size, min((i + 1) * batch_size, len(df)))
        batch = df.iloc[batch_slice]

        # Deal with melody
        melody_tensors = []
        for melody in batch['melody']:
            melody_events = melody._events
            melody_tensor = tf.convert_to_tensor(melody_events, dtype=tf.float32)
            melody_tensor = normalize(melody_tensor,-2, 127)
            # Calculate the number of fillers you need
            padding_needed = max_length - tf.shape(melody_tensor)[0]

            # Fill if padding_needed is greater than 0
            if padding_needed > 0:
                padded_melody_tensor = tf.pad(melody_tensor, [[0, padding_needed]], "CONSTANT")
            else:
                padded_melody_tensor = melody_tensor

            padded_melody_tensor = tf.expand_dims(padded_melody_tensor, -1)
            melody_tensors.append(padded_melody_tensor)

        features = np.array(batch[feature_col].tolist())
        augmented_features = augment_data(features)
        normalized_features = normalize(augmented_features, global_min_feature, global_max_feature)  # 归一化特征向量

        yield  (normalized_features, np.stack(melody_tensors)), np.stack(melody_tensors)

# %%
def created_dataset(df, features_col, batch_size, max_length):
    dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(df, features_col, batch_size, max_length),
    output_signature=(
        (tf.TensorSpec(shape=(None, np.stack(df[features_col].values).shape[1]), dtype=tf.float32),         # Adjust this as well
        tf.TensorSpec(shape=(None, max_length, 1), dtype=tf.float32)),  # Adjust the shape based on your actual data
        tf.TensorSpec(shape=(None, max_length, 1), dtype=tf.float32)
    )
)
    return dataset

# %% [markdown]
# ## Seperate the Dataset (Train data, Test data)

# %%
batch_size = 16
max_length = 81

dataset = created_dataset(base_data, 'features_mean', batch_size, max_length)

# Shuffle and seperate the dataset
dataset = dataset.shuffle(buffer_size=1000)
train_size = int(0.8 * sum(1 for _ in dataset))
train_dataset = dataset.take(train_size)
test_dataset = dataset.skip(train_size)

# Print out for verification
for (features, melodies), true_melodies in train_dataset.take(1):
    print("Train Melodies shape:", melodies.shape)
    print("Train Features shape:", features.shape)

for (features, melodies), true_melodies in test_dataset.take(1):
    print("Test Melodies shape:", melodies.shape)
    print("Test Features shape:", features.shape)
# Out:
# Train Melodies shape: (16, 81, 1)
# Train Features shape: (16, 512)
# Test Melodies shape: (16, 81, 1)
# Test Features shape: (16, 512)

# %%
# Print out for verification
for (features, melodies), true_melodies in train_dataset.take(1):
    print("Train Melodies shape:", melodies.numpy())
    print("Train Features shape:", features.numpy())
# Out:
# Train Melodies shape: [[[ 0.00775194]
#   [ 0.00775194]
#   [-0.03875971]
#   ...
#   [ 0.00775194]
#   [ 0.00775194]
#   [ 0.00775194]]
#
#  [[-1.        ]
#   [-1.        ]
#   [-1.        ]
#   ...
#   [ 0.        ]
#   [ 0.        ]
#   [ 0.        ]]
#
#  [[-0.19379842]
#   [-0.9844961 ]
#   [-0.19379842]
#   ...
#   [-0.25581396]
#   [-0.25581396]
#   [-0.25581396]]
#
#  ...
#
#  [[-1.        ]
#   [-1.        ]
#   [-1.        ]
#   ...
#   [-1.        ]
#   [-1.        ]
#   [-0.22480619]]
#
#  [[-0.19379842]
#   [-0.9844961 ]
#   [-0.19379842]
#   ...
#   [-0.25581396]
#   [-0.25581396]
#   [-0.25581396]]
#
#  [[-1.        ]
#   [ 0.05426359]
#   [ 0.05426359]
#   ...
#   [-0.05426359]
#   [-0.05426359]
#   [-0.05426359]]]
# Train Features shape: [[0.10377807 0.07855542 0.11653422 ... 0.13342968 0.07715635 0.07108741]
#  [0.14267929 0.13096079 0.15417345 ... 0.022183   0.08589421 0.12023375]
#  [0.14703806 0.08785785 0.07043544 ... 0.00354956 0.07039953 0.06056226]
#  ...
#  [0.13612051 0.09487528 0.13070239 ... 0.12816581 0.05463786 0.11328402]
#  [0.12414537 0.09823097 0.10988039 ... 0.14425237 0.07434651 0.1267578 ]
#  [0.11252523 0.06621277 0.11046889 ... 0.16177088 0.11598411 0.082987  ]]

# %% [markdown]
# ## Generative Model (VAE)

# %% [markdown]
# For feature vectors extracted by CLIP model, we may not need too complex encoder network, because these features are already at a high level of abstraction. As a result, the encoder can be simpler to keep this encoded high-level information, while the decoder may need more tweaking to produce a more detailed output (such as a music sequence).

# %% [markdown]
# ### Sampling

# %% [markdown]
# The sampling function samples a potential vector from the normal distribution 𝑧 using the reparameterization trick. This function avoids the gradient propagation problem caused by random nodes and allows the model to be trained using backpropagation.

# %%
# Define the sampling function
def sampling(args):
    z_mean, z_log_sigma = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_sigma) * epsilon

# %% [markdown]
# ### Encoder

# %% [markdown]
# Since the input features are already highly abstract, encoders can be simplified or designed to be more focused on accommodating such high-dimensional features.
# The encoder maps the input data to the latent space, outputs the potential mean z_mean and the potential log-variance z_log_sigma, and uses the sampling function to generate the potential vector 𝑧.

# %%
class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        # The shape of the attention weight, with one weight for each feature
        self.W = self.add_weight(name='att_weight', shape=(input_shape[-1], input_shape[-1]),
                                 initializer='normal')
        self.b = self.add_weight(name='att_bias', shape=(input_shape[1],),
                                 initializer='zeros')
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        # Calculate the attention score for each time step
        e = K.tanh(K.dot(x, self.W) + self.b[:, None])
        a = K.softmax(e, axis=1)
        # Apply attention scores directly to features without extending dimensions
        output = x * a
        return output

    def compute_output_shape(self, input_shape):
        return input_shape

# %%
def build_encoder(input_dim, latent_dim):
    inputs = Input(shape=(input_dim,))
    x = Dense(512)(inputs)
    x = LeakyReLU(alpha=0.01)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)  # adjust Dropout ratio
    x = Dense(256)(x)
    x = LeakyReLU(alpha=0.01)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = Dense(128)(x)
    z_mean = Dense(latent_dim)(x)
    z_log_sigma = Dense(latent_dim)(x)

    z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_sigma])
    encoder = Model(inputs, [z_mean, z_log_sigma, z], name='encoder')
    encoder.summary()
    return encoder

# %% [markdown]
# ### Decoder

# %% [markdown]
# Learn how to generate concrete musical sequences from abstract features extracted from the latent space. Predict every note or event in Melody.

# %%
def build_decoder(latent_dim, output_dim):
    latent_inputs = Input(shape=(latent_dim,))
    x = Dense(128, activation='relu')(latent_inputs)
    x = RepeatVector(output_dim)(x)  # Expand the latent vector across the sequence
    x = LSTM(256, return_sequences=True)(x)  # LSTM to process these sequences
    x = AttentionLayer()(x)  # Applying attention over the sequence
    outputs = TimeDistributed(Dense(1, activation='tanh'))(x)  # Output at each time step

    decoder = Model(latent_inputs, outputs, name='decoder')
    decoder.summary()
    return decoder

# %% [markdown]
# ### VAE Model

# %%
# Custom refactoring losses
def reconstruction_loss(y_true, y_pred):
    # Calculate mean square error (MSE) losses
    mse_loss = K.mean(K.square(y_true - y_pred), axis=[1, 2])

    # Calculate the cosine similarity
    y_true_norm = K.l2_normalize(y_true, axis=1)
    y_pred_norm = K.l2_normalize(y_pred, axis=1)
    cosine_similarity = K.sum(y_true_norm * y_pred_norm, axis=2)

    # Calculating cosine similarity loss (1-cosine similarity)
    cosine_loss = 1 - cosine_similarity

    # Combination loss
    combined_loss = mse_loss + 0.5 * K.mean(cosine_loss, axis=1)
    return combined_loss

# Custom KL divergence loss
def kl_loss(z_mean, z_log_sigma):
    kl_loss = -0.5 * K.sum(1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma), axis=-1)
    return kl_loss

# The final combination loss
def vae_loss(true_melody, reconstructed_melody, z_mean, z_log_sigma, beta = 0.1):
    recon_loss = reconstruction_loss(true_melody, reconstructed_melody)
    kl = kl_loss(z_mean, z_log_sigma)
    return recon_loss + kl * beta

# %%
class VAE(Model):
    def __init__(self, encoder, decoder, beta=0.1, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.beta = beta

    def call(self, inputs):
        inputs, true_melody = inputs
        z_mean, z_log_sigma, z = self.encoder(inputs)
        reconstructed_melody = self.decoder(z)
        recon_loss = reconstruction_loss(true_melody, reconstructed_melody)
        kl = kl_loss(z_mean, z_log_sigma)
        total_loss = recon_loss + self.beta * kl
        self.add_loss(total_loss)
        self.add_metric(recon_loss, name='reconstruction_loss', aggregation='mean')
        self.add_metric(kl, name='kl_loss', aggregation='mean')
        return reconstructed_melody

# %%
# Build up the VAE model
def build_vae_models(input_dim, sequence_length, latent_dim, beta=0.1):
    inputs = Input(shape=(input_dim,), name="input_features")
    true_melody = Input(shape=(sequence_length, 1), name="true_melody")

    encoder = build_encoder(input_dim, latent_dim)
    decoder = build_decoder(latent_dim, sequence_length)

    z_mean, z_log_sigma, z = encoder(inputs)
    reconstructed_melody = decoder(z)

    # train model
    vae_train = VAE(encoder, decoder, beta)
    vae_train.compile(optimizer='adam')

    # predict model, do not need to input the Melody
    vae_predict = Model(inputs=inputs, outputs=reconstructed_melody, name='vae_predict')

    return vae_train, vae_predict

# %% [markdown]
# ## Train the Model

# %%
input_dim = 512  # input the dimension of features vector
sequence_length = 81  # output the length of music sequence
latent_dim = 64  # The dimensions of the latent space can be adjusted as needed

# create the model
vae_train,_ = build_vae_models(input_dim, sequence_length, latent_dim)
# Use the model's fit method for training
vae_train.fit(train_dataset, epochs=5, validation_data=test_dataset)
# Evaluate the model performancee
total_loss = vae_train.evaluate(test_dataset)
print("Test Loss:", total_loss)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 512)]        0           []
#
#  dense_7 (Dense)                (None, 512)          262656      ['input_3[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 512)          0           ['dense_7[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 512)         2048        ['leaky_re_lu_2[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 512)          0           ['batch_normalization_2[0][0]']
#
#  dense_8 (Dense)                (None, 256)          131328      ['dropout_2[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 256)          0           ['dense_8[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 256)         1024        ['leaky_re_lu_3[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 256)          0           ['batch_normalization_3[0][0]']
#
#  dense_9 (Dense)                (None, 128)          32896       ['dropout_3[0][0]']
#
#  dense_10 (Dense)               (None, 64)           8256        ['dense_9[0][0]']
#
#  dense_11 (Dense)               (None, 64)           8256        ['dense_9[0][0]']
#
#  lambda_1 (Lambda)              (None, 64)           0           ['dense_10[0][0]',
#                                                                   'dense_11[0][0]']
#
# ==================================================================================================
# Total params: 446,464
# Trainable params: 444,928
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 64)]              0
#
#  dense_12 (Dense)            (None, 128)               8320
#
#  repeat_vector_1 (RepeatVect  (None, 81, 128)          0
#  or)
#
#  lstm_1 (LSTM)               (None, 81, 256)           394240
#
#  attention_layer_1 (Attentio  (None, 81, 256)          65617
#  nLayer)
#
#  time_distributed_1 (TimeDis  (None, 81, 1)            257
#  tributed)
#
# =================================================================
# Total params: 468,434
# Trainable params: 468,434
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 21138/21138 [==============================] - 752s 35ms/step - loss: 0.7118 - reconstruction_loss: 0.6625 - kl_loss: 0.4930 - val_loss: 0.6639 - val_reconstruction_loss: 0.6639 - val_kl_loss: 8.2339e-07
# Epoch 2/5
# 21138/21138 [==============================] - 730s 34ms/step - loss: 0.6624 - reconstruction_loss: 0.6624 - kl_loss: 8.4974e-06 - val_loss: 0.6638 - val_reconstruction_loss: 0.6638 - val_kl_loss: 1.0049e-06
# Epoch 3/5
# 21138/21138 [==============================] - 714s 33ms/step - loss: 0.6624 - reconstruction_loss: 0.6624 - kl_loss: 1.3453e-05 - val_loss: 0.6640 - val_reconstruction_loss: 0.6640 - val_kl_loss: 5.1854e-06
# Epoch 4/5
# 21138/21138 [==============================] - 716s 33ms/step - loss: 0.6624 - reconstruction_loss: 0.6624 - kl_loss: 2.0913e-05 - val_loss: 0.6645 - val_reconstruction_loss: 0.6645 - val_kl_loss: 1.2126e-05
# Epoch 5/5
# 21138/21138 [==============================] - 718s 34ms/step - loss: 0.6624 - reconstruction_loss: 0.6624 - kl_loss: 1.1798e-05 - val_loss: 0.6640 - val_reconstruction_loss: 0.6640 - val_kl_loss: 5.0009e-06
# 5285/5285 [==============================] - 362s 17ms/step - loss: 0.6639 - reconstruction_loss: 0.6639 - kl_loss: 5.0002e-06
# Test Loss: [0.6639112234115601, 0.6639108061790466, 5.000223154638661e-06]

# %%
# save the model
vae_train.save_weights('my models/my_vae_weights23.h5')

# %% [markdown]
# ## Load the Trained Model

# %%
# load the model
input_dim = 512  # input the dimension of features vector
sequence_length = 81  # output the length of music sequence
latent_dim = 64  # The dimensions of the latent space can be adjusted as needed

_,model = build_vae_models(input_dim, sequence_length, latent_dim)
# load weights
model.load_weights('my models/my_vae_weights23.h5')
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 512)]        0           []
#
#  dense_14 (Dense)               (None, 512)          262656      ['input_5[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 512)          0           ['dense_14[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 512)         2048        ['leaky_re_lu_4[0][0]']
#  rmalization)
#
#  dropout_4 (Dropout)            (None, 512)          0           ['batch_normalization_4[0][0]']
#
#  dense_15 (Dense)               (None, 256)          131328      ['dropout_4[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 256)          0           ['dense_15[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 256)         1024        ['leaky_re_lu_5[0][0]']
#  rmalization)
#
#  dropout_5 (Dropout)            (None, 256)          0           ['batch_normalization_5[0][0]']
#
#  dense_16 (Dense)               (None, 128)          32896       ['dropout_5[0][0]']
#
#  dense_17 (Dense)               (None, 64)           8256        ['dense_16[0][0]']
#
#  dense_18 (Dense)               (None, 64)           8256        ['dense_16[0][0]']
#
#  lambda_2 (Lambda)              (None, 64)           0           ['dense_17[0][0]',
#                                                                   'dense_18[0][0]']
#
# ==================================================================================================
# Total params: 446,464
# Trainable params: 444,928
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 64)]              0
#
#  dense_19 (Dense)            (None, 128)               8320
#
#  repeat_vector_2 (RepeatVect  (None, 81, 128)          0
#  or)
#
#  lstm_2 (LSTM)               (None, 81, 256)           394240
#
#  attention_layer_2 (Attentio  (None, 81, 256)          65617
#  nLayer)
#
#  time_distributed_2 (TimeDis  (None, 81, 1)            257
#  tributed)
#
# =================================================================
# Total params: 468,434
# Trainable params: 468,434
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Test the Model

# %% [markdown]
# ### Load the Test Data

# %%
# image_add = "E:\\Project and Dissertation in Data Science\\dataset\\dataset\\test\\ivan-aivazovsky_sea-at-night-1861.jpg"
image_add = "E:\\Project and Dissertation in Data Science\\dataset\\artemis_official_data\\art_images\\vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890.jpg"
# text = "The steep mountains and the moonlight provide safety to the inhabitants of the isolated towns. "
# text = "I can imagine the sailors resting this peaceful night, dreaming of new adventures "
text = "She seems very happy in the picture, and you want to know what what is behind the smile. "

# %% [markdown]
# ### Extract Text-Image Features (CLIP Model)

# %%
# load pre-trained CLIP model
device = "cuda" if torch.cuda.is_available() else "cpu"
extracted_features_model, preprocess = clip.load("ViT-B/32", device=device)

# %%
# extract the images and text features
with torch.no_grad():
    image = Image.open(image_add).convert("RGB")
    image = preprocess(image).unsqueeze(0)
    # image feature
    image_feature = torch.cat([extracted_features_model.encode_image(image.to(device))]).cpu().numpy()

    # text feature
    text_tokens = clip.tokenize(text).to(device)
    text_feature = extracted_features_model.encode_text(text_tokens).cpu().numpy()

print('image features: ', image_feature.shape)
print('text features: ', text_feature.shape)
# Out:
# image features:  (1, 512)
# text features:  (1, 512)

# %%
feature_mean = (image_feature + text_feature) / 2
print(feature_mean.shape)
print(feature_mean)

feature_mean = augment_data(feature_mean)
augmented_features = normalize(feature_mean, global_min_feature, global_max_feature)

print(augmented_features.shape)
print(augmented_features)
# Out:
# (1, 512)
# [[ 1.1670e-01  2.0752e-03 -3.2288e-02  3.0060e-02  2.0422e-01 -1.3196e-01
#    1.0681e-02 -5.5029e-01 -3.5370e-02  3.3203e-01 -1.0632e-01  4.0131e-03
#    2.7002e-01  1.8604e-01  3.2397e-01 -9.5215e-03  8.7830e-02 -2.3462e-01
#    3.7445e-02 -9.9182e-02  6.4160e-01  1.7737e-01 -2.1960e-01  1.7773e-01
#   -1.1566e-02 -6.7932e-02  1.9531e-01 -6.2378e-02 -8.5938e-02 -3.8965e-01
#    1.7249e-01  2.4951e-01 -1.2817e-01  3.3875e-02  1.8884e-01  1.5076e-01
#    1.5381e-01 -9.2407e-02  1.0217e-01  1.0339e-01  5.9875e-02  3.9429e-02
#   -5.1941e-02  1.3184e-01  1.0071e-01  1.6919e-01 -2.0691e-01  4.3726e-01
#    2.4609e-01 -8.9600e-02  1.8506e-01  6.9397e-02  1.6870e-01 -1.9824e-01
#   -5.8075e-02 -2.5195e-01  1.6016e-01  2.1777e-01 -1.6504e-01  6.5369e-02
#    4.9805e-01  1.0767e-01  1.8799e-01 -3.5767e-02  1.9214e-01  4.5532e-02
#    2.4438e-01  2.5098e-01  1.7004e-01 -7.0557e-02  1.9080e-01  2.2644e-02
#    1.8079e-01 -1.3354e-01 -8.8257e-02  8.4351e-02  4.1162e-01 -2.8648e-03
#    1.1035e-01  3.1494e-01  1.1902e-02  3.3374e-01 -1.2427e-01 -1.0651e-01
#    3.3264e-02  2.7002e-01  5.1660e-01 -2.8442e-01 -2.5854e-01 -8.7097e-02
#   -1.3831e-01 -1.0101e-01 -2.9492e+00 -5.9174e-02  8.1635e-03 -1.3525e-01
#    9.4604e-03  3.3813e-02 -7.9285e-02  6.9458e-02  2.1826e-01 -1.0657e-01
#   -4.0344e-02 -1.2720e-01  1.8286e-01  7.5073e-02  1.0254e-01  3.5327e-01
#   -6.7444e-02 -1.0376e-02 -6.9946e-02 -3.0542e-01 -1.7639e-02  1.6614e-01
#   -1.5320e-02 -1.1853e-01 -8.7952e-02  5.7983e-03 -1.0938e-01  1.7737e-01
#   -1.4282e-02 -2.6782e-01 -1.7456e-02 -6.1035e-05  2.1411e-01 -2.3804e-01
#    1.9946e-01 -1.1194e-01  2.3218e-01  5.5176e-01  2.5000e-01  5.1392e-02
#   -1.5967e-01  3.4414e+00 -1.3782e-01  1.5083e-02 -2.3499e-01 -1.7456e-02
#    3.6084e-01  1.0962e-01 -1.2524e-01  2.4390e-01  1.8042e-01  2.5146e-01
#    9.8022e-02 -8.1787e-02 -1.3237e-02  2.4438e-01 -2.7344e-01  5.7678e-03
#   -1.1475e-01  9.1736e-02  1.0156e-01 -4.1626e-02  8.1909e-02 -1.5259e-01
#   -1.3596e-02 -4.4971e-01 -2.5562e-01  2.8491e-01 -2.6294e-01  3.8818e-02
#   -6.6345e-02  3.6011e-02 -1.0022e-01  7.8003e-02  1.4941e-01  1.3721e-01
#   -4.1943e-01 -1.2891e-01 -4.8828e-04 -2.3462e-01  4.8608e-01  1.4526e-02
#   -1.2329e-02 -1.0022e-01 -4.1718e-02  2.0117e-01  7.1094e-01 -2.3877e-01
#    8.1055e-02 -1.0101e-01  2.4323e-02 -5.9375e-01 -2.6489e-01 -1.2817e-01
#    1.0883e-01 -8.3862e-02 -1.7407e-01  7.4829e-02  1.3306e-01  1.4941e-01
#    1.4795e-01  1.0022e-01  1.1609e-01  5.0354e-03 -4.6997e-02  4.0894e-01
#   -4.0649e-01 -1.3647e-01  1.7883e-02 -2.9443e-01 -1.6345e-01  3.1250e-01
#   -7.9651e-03 -2.4841e-01 -1.1877e-01  1.3733e-01  2.0972e-01  1.7346e-01
#    4.5020e-01  4.0210e-01 -1.9257e-02  1.6235e-02 -1.6260e-01  3.2715e-01
#    2.3608e-01 -2.7930e-01  3.4863e-01  2.2156e-01  3.1372e-02 -1.1407e-01
#    9.6313e-02  6.5247e-02 -2.2766e-01  9.5581e-02 -2.1454e-02  4.2358e-02
#   -2.4719e-01 -2.0996e-01 -4.3457e-01  1.0535e-01 -1.1096e-01  1.9238e-01
#    1.3892e-01 -2.5342e-01 -9.3628e-02  1.3232e-01 -1.6064e-01  2.4890e-01
#    2.9053e-01  1.5186e-01 -1.8457e-01 -2.3889e-01 -1.1609e-01 -1.4526e-02
#    2.8320e-01 -1.8738e-01  1.5625e-02 -5.8105e-02  3.1494e-01 -2.9614e-01
#    8.0200e-02 -2.2803e-01  3.2745e-02 -1.7432e-01  1.6711e-01 -1.2390e-01
#   -1.2573e-01 -4.4556e-03  2.7051e-01 -8.1665e-02 -3.1030e-01 -8.5449e-02
#    9.0332e-02  2.2632e-01 -1.0083e-01 -7.5012e-02 -5.3040e-02 -2.6221e-01
#   -1.9177e-01  4.3457e-01  5.2246e-01 -1.2671e-01  4.6783e-02  2.2766e-01
#    1.6406e-01  1.1633e-01  2.0093e-01 -1.1285e-01  9.9304e-02 -7.0679e-02
#    1.9189e-01  2.3376e-02 -2.6123e-01 -4.3945e-03 -6.6357e-01  3.6987e-02
#    1.3379e-01  8.7128e-03  1.2244e-01  8.1299e-02  2.0581e-01  2.4063e-02
#    1.0895e-01  2.9480e-02 -1.0223e-02 -2.0203e-02 -3.6652e-02  1.6113e-02
#    3.0579e-02 -2.6538e-01 -1.5356e-01 -2.9633e-02 -3.3508e-02  2.9810e-01
#    3.5522e-02  3.7134e-01  8.6792e-02 -7.4646e-02  7.4707e-02  6.7078e-02
#    3.4355e+00  5.5298e-02  1.2939e-01  2.6978e-01 -2.0248e-02 -1.0138e-01
#    1.1914e-01  1.0742e-02  1.5100e-01  8.5498e-01  8.4106e-02  1.7346e-01
#   -3.3887e-01 -1.7624e-02 -5.1331e-02  2.2522e-02  3.0298e-01 -1.1562e+00
#   -5.8075e-02  8.4045e-02  2.4414e-01 -6.3843e-02 -3.1677e-02  3.5950e-02
#    3.9886e-02 -6.8054e-02 -3.6426e-01  1.1603e-01 -8.9294e-02 -2.4341e-01
#   -1.6309e-01  2.2675e-02 -1.0815e-01  1.6113e-01  2.3633e-01 -3.5156e-02
#   -7.8491e-02 -1.5198e-01 -1.9836e-01  4.3121e-02 -3.4027e-02  6.2866e-02
#    1.6211e-01  5.4639e-01 -1.0388e-01 -2.9028e-01 -1.5149e-01  1.7212e-02
#    3.8574e-01 -1.7334e-01  2.7441e-01  1.6187e-01 -6.2354e-01 -9.4788e-02
#   -1.5503e-01 -9.6741e-02  1.7908e-01 -1.8311e-04  1.6602e-01 -3.7354e-01
#    6.4087e-02  6.7993e-02 -2.3218e-01 -1.6394e-01  7.4414e-01  1.1334e-01
#   -3.0566e-01 -6.6528e-03  3.8672e-01 -3.3691e-02 -2.1378e-02 -2.4170e-01
#    6.2073e-02  1.4453e-01 -1.1768e-01 -1.8860e-02 -2.8491e-01  1.1055e+00
#   -3.6182e-01 -1.5137e-01 -1.1212e-01  2.0715e-01 -1.3794e-01  6.3599e-02
#   -1.2122e-01 -6.7322e-02  1.0327e-01 -2.2705e-01  1.2772e-02  4.8706e-02
#    2.2034e-01 -1.1230e-02  6.1035e-04  2.9102e-01  1.4697e-01 -6.3843e-02
#    1.8835e-01  3.8483e-02 -4.8438e-01 -4.4922e-02 -1.4282e-02 -1.2561e-01
#    2.1924e-01 -3.8483e-02 -9.9915e-02 -1.0651e-01 -2.5122e-01  1.8262e-01
#    8.0322e-02 -9.1736e-02  6.3477e-03  1.5942e-01  3.3356e-02 -6.6406e-02
#    2.6758e-01 -2.5635e-01  2.2559e-01 -3.1433e-03  2.2266e-01  2.6611e-01
#    8.0225e-01 -2.6978e-01 -2.3206e-01  3.5010e-01 -3.0859e-01 -2.6001e-01
#   -2.0361e-01 -2.9980e-01 -8.9172e-02  5.6702e-02 -3.2666e-01 -3.0518e-03
#   -6.1157e-02  2.0654e-01 -4.7302e-02 -2.9572e-02  1.8262e-01  8.2031e-02
#    4.4287e-01 -5.4492e-01  8.5693e-02  1.1206e-01  7.1838e-02  1.2805e-01
#   -6.0638e-02  1.3245e-01 -3.4277e-01  1.7041e-01 -1.5869e-02 -5.8258e-02
#    1.3757e-01 -2.0898e-01  1.6748e-01 -1.4001e-01  2.4182e-01 -9.7290e-02
#   -1.0602e-01 -1.7261e-01  3.0762e-02 -1.9556e-01 -1.6260e-01 -6.9275e-03
#    2.0996e-01  2.8076e-01  1.4001e-01  1.3806e-01  3.0029e-01  1.0229e-01
#   -4.8645e-02 -3.1567e-01  1.1462e-01 -1.8018e-01 -4.4403e-02 -6.8237e-02
#    1.3245e-01  1.5442e-02 -4.3091e-02  2.6489e-01  1.7334e-01  1.9617e-01
#    9.8083e-02  2.8564e-01  3.1738e-02 -2.6099e-01  6.7993e-02 -9.4604e-02
#    1.0901e-01 -1.6174e-02  1.7163e-01 -4.8584e-02  9.4238e-02  2.8046e-02
#    4.1357e-01  1.4111e-01 -2.3315e-02 -1.0242e-01 -1.5527e-01 -1.0785e-01
#   -1.5454e-01  1.0590e-01]]
# (1, 512)
# [[ 1.09708146e-01  1.47363874e-01 -1.56786003e-01  5.83052666e-02
#    2.82286639e-01 -1.10869610e-02 -1.62819581e-01 -5.09269541e-01
#    2.59616593e-02  4.26950253e-01 -9.29451794e-02  5.53873040e-02
#    3.72825903e-01  2.07991035e-01  3.10682946e-01 -8.88044738e-03
#    7.62315614e-02 -2.13196734e-01 -1.73350360e-04 -1.32031645e-01
#    7.54344524e-01  3.63144178e-01 -2.60009916e-01  1.06372134e-01
#    1.50916319e-02  1.66106790e-02  2.61695182e-01 -1.25365743e-01
#   -1.51510012e-01 -4.50176447e-01  2.80427081e-01  3.52287465e-02
#   -7.22783037e-03  1.60015932e-01  3.91706555e-01  9.75416079e-02
#    1.23950947e-01  4.37014654e-02  3.82076160e-01  6.72110377e-02
#    1.31333512e-01 -1.71540709e-01 -1.09100486e-01  1.14341107e-01
#   -7.15068774e-02  1.71593035e-01 -2.84209918e-02  3.15822514e-01
#    1.81755713e-01  1.18940621e-01  2.53964946e-01 -8.52435600e-02
#    1.85351162e-01 -3.06933833e-01 -4.60779266e-02 -3.03365502e-01
#    3.36065573e-01  9.94220381e-02 -1.42928085e-01  1.10595999e-01
#    4.77630191e-01  3.45611514e-01  3.66369068e-01  1.59389268e-01
#    1.48897895e-01  9.59130207e-02  2.41445321e-01  2.31357947e-01
#    3.35196578e-01 -1.85166982e-01  1.30062484e-01  1.00912335e-01
#    2.18810562e-01 -2.96191663e-01 -2.36530309e-01  5.70419401e-02
#    3.67509680e-01 -7.31772173e-02  1.87428086e-01  4.41609983e-01
#   -1.37286976e-01  3.16651188e-01 -2.05519406e-01 -5.24815751e-02
#    1.58432574e-01  1.73240909e-01  3.29489967e-01 -1.29589651e-01
#   -6.86830163e-02 -1.20438554e-01 -1.52412057e-01 -1.44768186e-01
#   -2.95822237e+00 -4.69158212e-02  1.16250087e-01 -2.13480955e-01
#    1.00439254e-01  1.10261222e-02  4.03964633e-02  5.18753231e-02
#    1.30273325e-01  2.84420367e-02 -9.55653865e-02 -1.55972805e-01
#    2.72294948e-01 -1.00198209e-02  4.56682381e-02  4.54198080e-01
#    2.53882816e-02  1.98791976e-01 -1.79151366e-01 -4.98227211e-01
#    2.36626803e-02  1.66307540e-01  9.14248206e-02 -1.87962539e-01
#   -5.01288464e-02 -1.42126196e-02 -1.29188415e-01  1.42264562e-01
#    1.45351410e-02 -4.54688880e-01  3.25436305e-02 -2.04136082e-01
#    3.08552801e-01 -3.40090519e-01  3.01830043e-01  2.79213196e-02
#    1.59252615e-01  6.37754605e-01  2.94633674e-01  1.21950918e-01
#   -2.09397310e-01  3.40775358e+00 -6.23112898e-03 -5.45744760e-02
#   -1.11996118e-01  3.01744656e-03  4.69771545e-01  2.61920963e-01
#   -1.29012438e-01  3.76666436e-01  2.00727882e-01  1.99962188e-01
#    9.75243367e-02 -1.23836850e-01  5.19463134e-02  8.45022599e-02
#   -2.92792408e-01 -7.32624763e-02 -2.34393794e-02  4.05262194e-02
#    2.78040354e-01  3.90363403e-02  1.50260048e-01 -5.15872934e-02
#    1.79517002e-02 -4.79874778e-01 -3.30145616e-01  3.92128428e-01
#   -2.63403751e-01  1.84717552e-01 -1.98363232e-01  1.08692491e-01
#   -1.75909866e-01 -2.43047093e-01  1.84020138e-01  6.31033518e-02
#   -4.02208173e-01 -3.17702319e-02 -3.53599936e-02 -2.81207153e-01
#    3.74600072e-01 -5.26500373e-02 -1.23120622e-01 -2.39082367e-02
#   -4.09717216e-02  1.21063292e-01  5.75804030e-01 -2.26923434e-01
#    2.95409000e-01 -2.24846852e-01  1.64034401e-03 -5.84571505e-01
#   -2.06153759e-01  4.48525260e-03 -2.54901740e-02 -1.22253397e-01
#   -1.07372545e-01  2.07736388e-01  2.46914729e-01  9.88210062e-02
#    2.38548515e-01  1.50838583e-01  6.88570713e-02  1.46811767e-01
#   -1.99586454e-02  2.81381339e-01 -4.37388650e-01 -2.03426800e-01
#    1.11023063e-01 -3.67174675e-01 -1.49104357e-01  3.07526093e-01
#   -3.46559002e-02 -4.43808284e-01 -1.52316915e-01  9.31906114e-02
#    1.62580072e-01  2.85057236e-01  3.13170195e-01  4.31049710e-01
#   -9.67507703e-02 -3.86616146e-02 -2.58060625e-01  3.59660472e-01
#    2.69668907e-01 -3.11718387e-01  4.61715753e-01  7.41894908e-02
#    5.71422758e-02 -1.62951808e-01  2.43544831e-01  3.30707553e-01
#   -3.20799494e-02 -3.13170029e-02  1.25818259e-02 -5.28932935e-02
#   -1.83042439e-01  1.96646697e-02 -3.73208170e-01  1.86627277e-01
#   -1.57384889e-01  1.13282566e-01  2.96013877e-01 -2.16283168e-01
#   -1.62758698e-01  2.24671266e-01 -2.88540155e-01  3.03612413e-01
#    2.20312106e-01  3.60353387e-01 -9.87033806e-02 -1.56484656e-01
#   -1.10474235e-01 -9.29521515e-02  3.59644667e-01 -1.51168092e-01
#    3.32757446e-02 -2.20031797e-01  4.56735480e-01 -2.59530995e-01
#    8.49186099e-02 -2.37783561e-01  1.26648072e-01 -8.41144281e-02
#    1.89236418e-02 -2.00036742e-01 -2.58297063e-01 -7.91613334e-03
#    4.00442628e-01 -2.51365257e-02 -2.33767724e-01 -1.40445868e-01
#    4.14887047e-02  1.69776590e-01 -4.53888273e-02  5.47395016e-02
#   -4.49542130e-02 -2.93169599e-01 -1.73561934e-01  3.03912116e-01
#    2.54782822e-01 -1.39584065e-01 -6.08073212e-04  3.17368271e-01
#    2.68137687e-01  1.07345386e-01  1.27153181e-01  3.17205024e-02
#    1.95646947e-01 -6.47706205e-02  1.05449448e-01 -8.43784298e-02
#   -4.70356490e-01  1.48583071e-01 -4.96383564e-01 -2.30672152e-02
#    3.18245821e-01 -1.36413056e-01  2.37220002e-01  3.02484836e-01
#    1.46583586e-01  4.12567634e-02  3.90370121e-02  2.67236656e-02
#   -1.29345421e-02 -8.75103455e-02 -9.79062527e-02 -6.29799670e-02
#    2.05538281e-01 -1.59046952e-01 -1.23402800e-01 -1.11549308e-01
#    4.08253686e-02  3.06210083e-01  7.79419323e-03  4.58318759e-01
#    1.59636308e-01 -2.95831441e-01  1.97438532e-02  3.08598685e-01
#    3.48371116e+00  2.15506245e-01 -3.01751142e-02  9.70127905e-02
#    5.00399249e-03 -1.08755714e-01  1.43781604e-01  5.35532022e-02
#    2.66831122e-01  8.24849682e-01  4.30658528e-02  1.69303085e-01
#   -2.10322006e-01 -6.13088192e-02 -7.89199305e-02  4.92875916e-02
#    1.76756464e-01 -1.13159113e+00 -1.46707043e-01  3.58967829e-02
#    4.51931864e-01 -1.53974067e-01  3.40443470e-02 -7.29826498e-03
#   -3.31378097e-02 -6.53620093e-02 -2.93280014e-01 -2.13619943e-03
#   -3.38870391e-02 -2.97809985e-01 -1.81343846e-01  8.55897011e-02
#   -9.43980052e-02  1.52222167e-01  2.36982869e-01 -1.74789051e-01
#   -1.08744682e-01 -2.14687684e-02 -5.27206520e-02  2.46243359e-01
#    1.10524074e-01  2.36336297e-01  7.28366230e-02  3.82491558e-01
#   -2.84400999e-01 -2.56511764e-01 -3.00388665e-02 -1.04709712e-01
#    5.02068912e-01 -3.09862823e-01  1.51618165e-01  2.88102458e-01
#   -6.31613367e-01 -4.28591318e-03 -3.21330424e-01 -6.18081689e-02
#    9.41108634e-02  3.81748072e-02  4.06866775e-01 -3.15708745e-01
#    9.51757295e-02 -2.08468569e-01 -1.38260680e-01 -2.21594225e-01
#    7.66276266e-01  8.84529437e-02 -2.68901173e-01  4.80582090e-02
#    5.23639371e-01 -6.30876487e-02 -4.33574706e-02 -3.12514540e-01
#    1.06087030e-01  2.14701777e-01 -4.00107233e-02  3.64394954e-02
#   -3.71721236e-01  1.14199253e+00 -1.71950846e-01 -1.25343046e-01
#   -2.42123370e-01  2.14370668e-01 -2.18048444e-01  1.14027247e-01
#   -2.48531927e-01 -6.75537703e-03  2.02706496e-01 -1.67990848e-01
#   -1.34117430e-01  6.00249608e-02  3.08249574e-01 -2.98409448e-03
#    1.86834173e-01  2.25164125e-01  2.83573315e-01 -3.03543891e-02
#    3.64314171e-01 -3.22054344e-02 -5.97040042e-01 -1.66441218e-02
#    6.49517337e-02  2.97637717e-02  1.70566259e-01  1.45516318e-02
#    1.23135578e-01 -4.95709012e-02 -1.81057669e-01 -1.42353633e-01
#    2.04585400e-01 -1.29651889e-01  3.26344267e-03 -1.82856866e-03
#    7.53261478e-02 -4.34326090e-02  4.53694216e-01 -1.85459738e-01
#    2.09093429e-01 -1.68531874e-02  1.51605016e-01  2.52897645e-01
#    9.01157792e-01 -4.20016649e-01 -1.03709382e-01  5.67077259e-01
#   -5.34110332e-01 -1.88093490e-01 -2.35488419e-01 -2.78785664e-01
#   -1.38999590e-01  1.94521611e-01 -3.76925038e-01 -1.17505670e-01
#   -4.30831377e-02  1.88561542e-01 -1.33191109e-01 -6.97733295e-02
#    8.43486131e-02 -2.79112096e-02  5.27906662e-01 -5.48100102e-01
#    4.07669012e-02  1.60886695e-01  4.15646585e-02  2.09137859e-01
#   -1.79200637e-01  9.98424227e-02 -2.66498759e-01  1.16551657e-01
#    5.68289986e-03 -9.71686125e-02  1.96942550e-01 -3.07755980e-01
#    1.44545403e-01 -1.77746337e-01  1.38970650e-01  1.72466142e-01
#   -1.71564147e-01 -3.68791652e-01  5.14752267e-02 -1.79360095e-01
#   -3.42412540e-02  6.81354797e-02  2.42710071e-01  1.54776897e-01
#    1.62668529e-01  1.60621042e-01  3.10281191e-01  2.59688948e-01
#    1.52937160e-03 -2.48382222e-01  1.14606604e-01 -3.35821772e-01
#   -2.67381554e-01  1.08274875e-01  2.26708235e-01 -5.77571149e-03
#   -2.03905145e-01  1.60399347e-01  9.23055457e-02  2.00697856e-01
#    3.29654454e-04  3.89622365e-01  9.11070791e-02 -2.69610115e-01
#   -1.38728177e-01 -9.71552101e-02  1.04836449e-01  4.96008349e-02
#    3.18593600e-01 -1.50562723e-01  1.75962208e-01 -1.37414805e-01
#    2.91098409e-01  3.35722132e-01 -1.81054139e-01 -6.21712987e-03
#   -1.73153077e-01  3.88285516e-02 -2.68248464e-01 -6.13813800e-02]]

# %% [markdown]
# ### Prediction

# %%
# generate the Melody by model
predicted_melody = model.predict(augmented_features)

print(predicted_melody)
print(predicted_melody.shape)
# Out:
# 1/1 [==============================] - 0s 14ms/step
# [[[-0.6541066 ]
#   [-0.5989141 ]
#   [-0.43887112]
#   [-0.42253333]
#   [-0.5064967 ]
#   [-0.422007  ]
#   [-0.38771096]
#   [-0.35585967]
#   [-0.35427618]
#   [-0.30234623]
#   [-0.31662163]
#   [-0.39002553]
#   [-0.32184502]
#   [-0.36942178]
#   [-0.3471425 ]
#   [-0.3311268 ]
#   [-0.3037322 ]
#   [-0.26689512]
#   [-0.35566077]
#   [-0.32961607]
#   [-0.35278666]
#   [-0.3412085 ]
#   [-0.33233738]
#   [-0.29835996]
#   [-0.28489482]
#   [-0.38073593]
#   [-0.3366217 ]
#   [-0.29435077]
#   [-0.3593678 ]
#   [-0.3990304 ]
#   [-0.2974333 ]
#   [-0.3075731 ]
#   [-0.31702676]
#   [-0.30432314]
#   [-0.27330768]
#   [-0.2616552 ]
#   [-0.24253267]
#   [-0.2915615 ]
#   [-0.24044141]
#   [-0.29748783]
#   [-0.27062172]
#   [-0.213168  ]
#   [-0.27500087]
#   [-0.28376633]
#   [-0.26739392]
#   [-0.22076833]
#   [-0.2853713 ]
#   [-0.30103263]
#   [-0.30647826]
#   [-0.31798163]
#   [-0.33147344]
#   [-0.27773973]
#   [-0.28581974]
#   [-0.3088387 ]
#   [-0.33184737]
#   [-0.31911492]
#   [-0.25152037]
#   [-0.35370606]
#   [-0.3362536 ]
#   [-0.3220287 ]
#   [-0.28440416]
#   [-0.32462156]
#   [-0.31543747]
#   [-0.33169153]
#   [-0.2604405 ]
#   [-0.22227071]
#   [-0.30504343]
#   [-0.29295853]
#   [-0.3211058 ]
#   [-0.31247658]
#   [-0.28408566]
#   [-0.2282576 ]
#   [-0.22719823]
#   [-0.24812615]
#   [-0.23283215]
#   [-0.1839012 ]
#   [-0.22664565]
#   [-0.23442039]
#   [-0.16977863]
#   [-0.09171622]
#   [-0.08463746]]]
# (1, 81, 1)

# %%
predicted_melody = denormalize(predicted_melody, -2, 127)

print(predicted_melody)
print(predicted_melody.shape)
# Out:
# [[[20.310123]
#   [23.87004 ]
#   [34.19281 ]
#   [35.2466  ]
#   [29.830961]
#   [35.280552]
#   [37.492645]
#   [39.547054]
#   [39.649185]
#   [42.99867 ]
#   [42.077904]
#   [37.343357]
#   [41.740993]
#   [38.672295]
#   [40.10931 ]
#   [41.142323]
#   [42.909275]
#   [45.285267]
#   [39.55988 ]
#   [41.239765]
#   [39.745262]
#   [40.492054]
#   [41.06424 ]
#   [43.25578 ]
#   [44.124283]
#   [37.94253 ]
#   [40.7879  ]
#   [43.514378]
#   [39.320778]
#   [36.76254 ]
#   [43.315556]
#   [42.661537]
#   [42.051777]
#   [42.87116 ]
#   [44.871655]
#   [45.623238]
#   [46.856644]
#   [43.694283]
#   [46.991528]
#   [43.312035]
#   [45.0449  ]
#   [48.750664]
#   [44.762444]
#   [44.19707 ]
#   [45.25309 ]
#   [48.26044 ]
#   [44.09355 ]
#   [43.083393]
#   [42.73215 ]
#   [41.99019 ]
#   [41.11996 ]
#   [44.585785]
#   [44.064625]
#   [42.579903]
#   [41.095844]
#   [41.917088]
#   [46.276936]
#   [39.68596 ]
#   [40.81164 ]
#   [41.72915 ]
#   [44.155933]
#   [41.56191 ]
#   [42.154285]
#   [41.1059  ]
#   [45.70159 ]
#   [48.16354 ]
#   [42.824696]
#   [43.604176]
#   [41.788673]
#   [42.34526 ]
#   [44.176476]
#   [47.777386]
#   [47.845715]
#   [46.495865]
#   [47.482327]
#   [50.638374]
#   [47.881355]
#   [47.379883]
#   [51.54928 ]
#   [56.584305]
#   [57.040882]]]
# (1, 81, 1)

# %%
predicted_notes = np.round(predicted_melody).astype(int)
print(predicted_notes)
# Out:
# [[[20]
#   [24]
#   [34]
#   [35]
#   [30]
#   [35]
#   [37]
#   [40]
#   [40]
#   [43]
#   [42]
#   [37]
#   [42]
#   [39]
#   [40]
#   [41]
#   [43]
#   [45]
#   [40]
#   [41]
#   [40]
#   [40]
#   [41]
#   [43]
#   [44]
#   [38]
#   [41]
#   [44]
#   [39]
#   [37]
#   [43]
#   [43]
#   [42]
#   [43]
#   [45]
#   [46]
#   [47]
#   [44]
#   [47]
#   [43]
#   [45]
#   [49]
#   [45]
#   [44]
#   [45]
#   [48]
#   [44]
#   [43]
#   [43]
#   [42]
#   [41]
#   [45]
#   [44]
#   [43]
#   [41]
#   [42]
#   [46]
#   [40]
#   [41]
#   [42]
#   [44]
#   [42]
#   [42]
#   [41]
#   [46]
#   [48]
#   [43]
#   [44]
#   [42]
#   [42]
#   [44]
#   [48]
#   [48]
#   [46]
#   [47]
#   [51]
#   [48]
#   [47]
#   [52]
#   [57]
#   [57]]]

# %%
melody = note_seq.Melody(predicted_notes.flatten().tolist())
melody

# %%
melody._events
# Out:
# [20,
#  24,
#  34,
#  35,
#  30,
#  35,
#  38,
#  40,
#  40,
#  43,
#  42,
#  38,
#  42,
#  39,
#  40,
#  41,
#  43,
#  45,
#  40,
#  41,
#  40,
#  41,
#  41,
#  43,
#  44,
#  38,
#  41,
#  44,
#  40,
#  37,
#  43,
#  43,
#  42,
#  43,
#  45,
#  45,
#  47,
#  44,
#  47,
#  43,
#  45,
#  49,
#  45,
#  44,
#  45,
#  48,
#  44,
#  43,
#  43,
#  42,
#  41,
#  44,
#  44,
#  43,
#  41,
#  42,
#  46,
#  40,
#  41,
#  42,
#  44,
#  42,
#  42,
#  41,
#  46,
#  48,
#  43,
#  44,
#  42,
#  42,
#  44,
#  48,
#  48,
#  46,
#  47,
#  51,
#  48,
#  47,
#  52,
#  57,
#  57]

# %% [markdown]
# ## Sentiment Analysis text content: Calculate the range of QPM

# %%
# Load the emotional vocabulary dictionary
positive_words = set(opinion_lexicon.positive())
negative_words = set(opinion_lexicon.negative())

# Words that define calm and excitement
calm_words = {
    'peaceful', 'calm', 'relaxed', 'serene', 'tranquil', 'composed', 'quiet', 'soothing',
    'content', 'easygoing', 'gentle', 'harmonious', 'placid', 'mellow', 'restful',
    'untroubled', 'cool', 'collected'
}
excited_words = {
    'excited', 'energetic', 'lively', 'thrilled', 'exhilarated', 'animated', 'enthusiastic',
    'vivacious', 'vibrant', 'spirited', 'eager', 'dynamic', 'passionate', 'zealous',
    'high-spirited', 'raring', 'buoyant', 'stimulated'
}

def sentiment_analysis(text):
    """
      Emotional analysis of the text
      Parameters:
      text (str) : The text to be analyzed
      Return value:
      sentiment_score (float) : Emotion score, ranging from -1 (negative) to 1 (positive)
      excitement_score (float) : excitability score, ranging from -1 (calm) to 1 (excited)
    """
    # Word segmentation
    words = word_tokenize(text.lower())

    # Count the number of positive emotion words, negative emotion words, calm words and excited words in the text
    num_positive_words = sum(1 for word in words if word in positive_words)
    num_negative_words = sum(1 for word in words if word in negative_words)
    num_neutral_words = len(words) - num_positive_words - num_negative_words
    num_calm_words = sum(1 for word in words if word in calm_words)
    num_excited_words = sum(1 for word in words if word in excited_words)

    # Calculate emotion score
    total_words = num_positive_words + num_negative_words + num_neutral_words
    sentiment_score = ((num_positive_words - num_negative_words) + num_neutral_words * 0.5) / max(1, total_words)

    # Calculate the excitement score
    total_emotion_words = num_calm_words + num_excited_words + num_neutral_words
    excitement_score = ((num_excited_words - num_calm_words) + num_neutral_words * 0.5) / max(1, total_emotion_words)

    return sentiment_score, excitement_score

def sentiment_to_qpm(sentiment, excitement):
    if excitement >= 0.5:
        if sentiment >= 0.5:
            return 60, 70  # Positive and excited
        elif sentiment > -0.5:
            return 40, 60  # Neutral and excited
        else:
            return 30, 40   # Negative and excited
    else:
        if sentiment >= 0.5:
            return 20, 30    # Positive and calm
        elif sentiment > -0.5:
            return 10, 20    # Neutral and calm
        else:
            return 5, 10    # Passive and calm

# Emotion index and excitability index were analyzed
sentiment_score, excitement_score = sentiment_analysis(text)
print('Sentiment Score:', sentiment_score)
print('Excitement Score:', excitement_score)

# Map to the qpm range
qpm_range = sentiment_to_qpm(sentiment_score, excitement_score)
print('QPM Range:', qpm_range)

# Select a qpm value at random
random_qpm = random.randint(qpm_range[0], qpm_range[1])
print('Random QPM:', random_qpm)
# Out:
# Sentiment Score: 0.5357142857142857
# Excitement Score: 0.39285714285714285
# QPM Range: (20, 30)
# Random QPM: 23

# %%
# Convert to a NoteSequence object
note_sequence = melody.to_sequence(velocity=100, instrument=0, program=0, sequence_start_time=0.0, qpm=random_qpm)

# Print the NoteSequence object
print(note_sequence)
# Out:
# ticks_per_quarter: 220
# tempos {
#   qpm: 23.0
# }
# notes {
#   pitch: 19
#   velocity: 100
#   end_time: 0.6521739130434783
# }
# notes {
#   pitch: 25
#   velocity: 100
#   start_time: 0.6521739130434783
#   end_time: 1.3043478260869565
# }
# notes {
#   pitch: 32
#   velocity: 100
#   start_time: 1.3043478260869565
#   end_time: 1.9565217391304348
# }
# notes {
#   pitch: 34
#   velocity: 100
#   start_time: 1.9565217391304348
#   end_time: 2.608695652173913
# }
# notes {
#   pitch: 30
#   velocity: 100
#   start_time: 2.608695652173913
#   end_time: 3.2608695652173916
# }
# notes {
#   pitch: 34
#   velocity: 100
#   start_time: 3.2608695652173916
#   end_time: 3.9130434782608696
# }
# notes {
#   pitch: 36
#   velocity: 100
#   start_time: 3.9130434782608696
#   end_time: 4.565217391304348
# }
# notes {
#   pitch: 39
#   velocity: 100
#   start_time: 4.565217391304348
#   end_time: 5.217391304347826
# }
# notes {
#   pitch: 39
#   velocity: 100
#   start_time: 5.217391304347826
#   end_time: 5.869565217391305
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 5.869565217391305
#   end_time: 6.521739130434783
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 6.521739130434783
#   end_time: 7.173913043478261
# }
# notes {
#   pitch: 36
#   velocity: 100
#   start_time: 7.173913043478261
#   end_time: 7.826086956521739
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 7.826086956521739
#   end_time: 8.478260869565217
# }
# notes {
#   pitch: 38
#   velocity: 100
#   start_time: 8.478260869565217
#   end_time: 9.130434782608695
# }
# notes {
#   pitch: 39
#   velocity: 100
#   start_time: 9.130434782608695
#   end_time: 9.782608695652174
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 9.782608695652174
#   end_time: 10.434782608695652
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 10.434782608695652
#   end_time: 11.08695652173913
# }
# notes {
#   pitch: 45
#   velocity: 100
#   start_time: 11.08695652173913
#   end_time: 11.73913043478261
# }
# notes {
#   pitch: 39
#   velocity: 100
#   start_time: 11.73913043478261
#   end_time: 12.391304347826088
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 12.391304347826088
#   end_time: 13.043478260869566
# }
# notes {
#   pitch: 39
#   velocity: 100
#   start_time: 13.043478260869566
#   end_time: 13.695652173913043
# }
# notes {
#   pitch: 40
#   velocity: 100
#   start_time: 13.695652173913043
#   end_time: 14.347826086956522
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 14.347826086956522
#   end_time: 15.0
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 15.0
#   end_time: 15.652173913043478
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 15.652173913043478
#   end_time: 16.304347826086957
# }
# notes {
#   pitch: 37
#   velocity: 100
#   start_time: 16.304347826086957
#   end_time: 16.956521739130434
# }
# notes {
#   pitch: 40
#   velocity: 100
#   start_time: 16.956521739130434
#   end_time: 17.608695652173914
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 17.608695652173914
#   end_time: 18.26086956521739
# }
# notes {
#   pitch: 38
#   velocity: 100
#   start_time: 18.26086956521739
#   end_time: 18.91304347826087
# }
# notes {
#   pitch: 36
#   velocity: 100
#   start_time: 18.91304347826087
#   end_time: 19.565217391304348
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 19.565217391304348
#   end_time: 20.217391304347828
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 20.217391304347828
#   end_time: 20.869565217391305
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 20.869565217391305
#   end_time: 21.52173913043478
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 21.52173913043478
#   end_time: 22.17391304347826
# }
# notes {
#   pitch: 45
#   velocity: 100
#   start_time: 22.17391304347826
#   end_time: 22.82608695652174
# }
# notes {
#   pitch: 46
#   velocity: 100
#   start_time: 22.82608695652174
#   end_time: 23.47826086956522
# }
# notes {
#   pitch: 47
#   velocity: 100
#   start_time: 23.47826086956522
#   end_time: 24.130434782608695
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 24.130434782608695
#   end_time: 24.782608695652176
# }
# notes {
#   pitch: 47
#   velocity: 100
#   start_time: 24.782608695652176
#   end_time: 25.434782608695652
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 25.434782608695652
#   end_time: 26.086956521739133
# }
# notes {
#   pitch: 45
#   velocity: 100
#   start_time: 26.086956521739133
#   end_time: 26.73913043478261
# }
# notes {
#   pitch: 48
#   velocity: 100
#   start_time: 26.73913043478261
#   end_time: 27.391304347826086
# }
# notes {
#   pitch: 45
#   velocity: 100
#   start_time: 27.391304347826086
#   end_time: 28.043478260869566
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 28.043478260869566
#   end_time: 28.695652173913043
# }
# notes {
#   pitch: 45
#   velocity: 100
#   start_time: 28.695652173913043
#   end_time: 29.347826086956523
# }
# notes {
#   pitch: 48
#   velocity: 100
#   start_time: 29.347826086956523
#   end_time: 30.0
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 30.0
#   end_time: 30.65217391304348
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 30.65217391304348
#   end_time: 31.304347826086957
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 31.304347826086957
#   end_time: 31.956521739130434
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 31.956521739130434
#   end_time: 32.608695652173914
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 32.608695652173914
#   end_time: 33.26086956521739
# }
# notes {
#   pitch: 45
#   velocity: 100
#   start_time: 33.26086956521739
#   end_time: 33.91304347826087
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 33.91304347826087
#   end_time: 34.56521739130435
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 34.56521739130435
#   end_time: 35.21739130434783
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 35.21739130434783
#   end_time: 35.869565217391305
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 35.869565217391305
#   end_time: 36.52173913043478
# }
# notes {
#   pitch: 46
#   velocity: 100
#   start_time: 36.52173913043478
#   end_time: 37.17391304347826
# }
# notes {
#   pitch: 39
#   velocity: 100
#   start_time: 37.17391304347826
#   end_time: 37.82608695652174
# }
# notes {
#   pitch: 40
#   velocity: 100
#   start_time: 37.82608695652174
#   end_time: 38.47826086956522
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 38.47826086956522
#   end_time: 39.130434782608695
# }
# notes {
#   pitch: 45
#   velocity: 100
#   start_time: 39.130434782608695
#   end_time: 39.78260869565217
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 39.78260869565217
#   end_time: 40.434782608695656
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 40.434782608695656
#   end_time: 41.08695652173913
# }
# notes {
#   pitch: 41
#   velocity: 100
#   start_time: 41.08695652173913
#   end_time: 41.73913043478261
# }
# notes {
#   pitch: 46
#   velocity: 100
#   start_time: 41.73913043478261
#   end_time: 42.391304347826086
# }
# notes {
#   pitch: 48
#   velocity: 100
#   start_time: 42.391304347826086
#   end_time: 43.04347826086956
# }
# notes {
#   pitch: 43
#   velocity: 100
#   start_time: 43.04347826086956
#   end_time: 43.69565217391305
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 43.69565217391305
#   end_time: 44.34782608695652
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 44.34782608695652
#   end_time: 45.0
# }
# notes {
#   pitch: 42
#   velocity: 100
#   start_time: 45.0
#   end_time: 45.65217391304348
# }
# notes {
#   pitch: 44
#   velocity: 100
#   start_time: 45.65217391304348
#   end_time: 46.30434782608696
# }
# notes {
#   pitch: 47
#   velocity: 100
#   start_time: 46.30434782608696
#   end_time: 46.95652173913044
# }
# notes {
#   pitch: 48
#   velocity: 100
#   start_time: 46.95652173913044
#   end_time: 47.608695652173914
# }
# notes {
#   pitch: 47
#   velocity: 100
#   start_time: 47.608695652173914
#   end_time: 48.26086956521739
# }
# notes {
#   pitch: 47
#   velocity: 100
#   start_time: 48.26086956521739
#   end_time: 48.91304347826087
# }
# notes {
#   pitch: 49
#   velocity: 100
#   start_time: 48.91304347826087
#   end_time: 49.56521739130435
# }
# notes {
#   pitch: 48
#   velocity: 100
#   start_time: 49.56521739130435
#   end_time: 50.21739130434783
# }
# notes {
#   pitch: 47
#   velocity: 100
#   start_time: 50.21739130434783
#   end_time: 50.869565217391305
# }
# notes {
#   pitch: 50
#   velocity: 100
#   start_time: 50.869565217391305
#   end_time: 51.52173913043478
# }
# notes {
#   pitch: 56
#   velocity: 100
#   start_time: 51.52173913043478
#   end_time: 52.173913043478265
# }
# notes {
#   pitch: 56
#   velocity: 100
#   start_time: 52.173913043478265
#   end_time: 52.82608695652174
# }
# total_time: 52.82608695652174

# %%
# Use FluidSynth to generate audio data
# Need to specify the SoundFont file path
# audio_samples = note_seq.fluidsynth(ns, sample_rate=44100, sf2_path='GeneralUser GS v1.471.sf2')
# audio_samples = note_seq.fluidsynth(ns, sample_rate=44100, sf2_path="TimGM6mb.sf2")
audio_samples = note_seq.fluidsynth(note_sequence, sample_rate=44100, sf2_path="FluidR3Mono_GM.sf3")

# Save audio data as WAV file
# 'audio_samples' is a floating-point audio array generated by fluidsynth
# Normalize audio and convert to 16-bit PCM format
write('generated_audios/output_audio_m12_2.wav', 44100, np.int16(audio_samples / np.max(np.abs(audio_samples)) * 32767))
